# %%
import pandapower as pp

#create empty net
net = pp.create_empty_network()

# %%
#create prime buses

bus1 = pp.create_bus(net, vn_kv=110, name="Bus 1")
bus2 = pp.create_bus(net, vn_kv=20, name="Bus 2")
bus3 = pp.create_bus(net, vn_kv=20, name="Bus 3")
bus4 = pp.create_bus(net, vn_kv=20, name="Bus 4")
bus5 = pp.create_bus(net, vn_kv=20, name="Bus 5")
bus6 = pp.create_bus(net, vn_kv=20, name="Bus 6")

# %%
#create second buses 4

bus41 = pp.create_bus(net, vn_kv=0.4, name="Bus 41")
bus42 = pp.create_bus(net, vn_kv=0.4, name="Bus 42")
bus43 = pp.create_bus(net, vn_kv=0.4, name="Bus 43")
bus44 = pp.create_bus(net, vn_kv=0.4, name="Bus 44")
bus45 = pp.create_bus(net, vn_kv=0.4, name="Bus 45")
bus46 = pp.create_bus(net, vn_kv=0.4, name="Bus 46")
bus47 = pp.create_bus(net, vn_kv=0.4, name="Bus 47")
bus48 = pp.create_bus(net, vn_kv=0.4, name="Bus 48")
bus49 = pp.create_bus(net, vn_kv=0.4, name="Bus 49")

# %%
#create second buses 5

bus51 = pp.create_bus(net, vn_kv=0.4, name="Bus 51")
bus52 = pp.create_bus(net, vn_kv=0.4, name="Bus 52")
bus53 = pp.create_bus(net, vn_kv=0.4, name="Bus 53")
bus54 = pp.create_bus(net, vn_kv=0.4, name="Bus 54")
bus55 = pp.create_bus(net, vn_kv=0.4, name="Bus 55")
bus56 = pp.create_bus(net, vn_kv=0.4, name="Bus 56")
bus57 = pp.create_bus(net, vn_kv=0.4, name="Bus 57")
bus58 = pp.create_bus(net, vn_kv=0.4, name="Bus 58")
bus59 = pp.create_bus(net, vn_kv=0.4, name="Bus 59")

# %%
#create second buses 6

bus61 = pp.create_bus(net, vn_kv=0.4, name="Bus 61")
bus62 = pp.create_bus(net, vn_kv=0.4, name="Bus 62")
bus63 = pp.create_bus(net, vn_kv=0.4, name="Bus 63")
bus64 = pp.create_bus(net, vn_kv=0.4, name="Bus 64")
bus65 = pp.create_bus(net, vn_kv=0.4, name="Bus 65")
bus66 = pp.create_bus(net, vn_kv=0.4, name="Bus 66")
bus67 = pp.create_bus(net, vn_kv=0.4, name="Bus 67")
bus68 = pp.create_bus(net, vn_kv=0.4, name="Bus 68")
bus69 = pp.create_bus(net, vn_kv=0.4, name="Bus 69")

# %%
#create grid

grid=pp.create_ext_grid(net, bus=bus1, s_sc_max_mva=100, s_sc_min_mva=80, rx_min=0.2, rx_max=0.35)

# %%
#create prime lines

line1 = pp.create_line(net, from_bus=bus2, to_bus=bus3, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=5, name="line1")
line2 = pp.create_line(net, from_bus=bus2, to_bus=bus4, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=6, name="line2")
line3 = pp.create_line(net, from_bus=bus2, to_bus=bus5, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=7, name="line3")
line4 = pp.create_line(net, from_bus=bus2, to_bus=bus6, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=6, name="line4")

# %%
#create second bus lines 4

line41 = pp.create_line(net, from_bus=bus41, to_bus=bus42, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line41")
line42 = pp.create_line(net, from_bus=bus42, to_bus=bus43, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line42")
line43 = pp.create_line(net, from_bus=bus43, to_bus=bus44, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line43")
line44 = pp.create_line(net, from_bus=bus44, to_bus=bus45, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line44")
line45 = pp.create_line(net, from_bus=bus45, to_bus=bus46, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line45")
line46 = pp.create_line(net, from_bus=bus46, to_bus=bus47, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line46")
line47 = pp.create_line(net, from_bus=bus47, to_bus=bus48, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line47")
line48 = pp.create_line(net, from_bus=bus48, to_bus=bus49, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line48")

# %%
#create second bus lines 5

line51 = pp.create_line(net, from_bus=bus51, to_bus=bus52, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line51")
line52 = pp.create_line(net, from_bus=bus52, to_bus=bus53, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line52")
line53 = pp.create_line(net, from_bus=bus53, to_bus=bus54, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line53")
line54 = pp.create_line(net, from_bus=bus54, to_bus=bus55, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line54")
line55 = pp.create_line(net, from_bus=bus55, to_bus=bus56, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line55")
line56 = pp.create_line(net, from_bus=bus56, to_bus=bus57, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line56")
line57 = pp.create_line(net, from_bus=bus57, to_bus=bus58, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line57")
line58 = pp.create_line(net, from_bus=bus58, to_bus=bus59, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line58")

# %%
#create second bus lines 6

line61 = pp.create_line(net, from_bus=bus61, to_bus=bus62, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line61")
line62 = pp.create_line(net, from_bus=bus62, to_bus=bus63, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line62")
line63 = pp.create_line(net, from_bus=bus63, to_bus=bus64, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line63")
line64 = pp.create_line(net, from_bus=bus64, to_bus=bus65, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line64")
line65 = pp.create_line(net, from_bus=bus65, to_bus=bus66, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line65")
line66 = pp.create_line(net, from_bus=bus66, to_bus=bus67, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line66")
line67 = pp.create_line(net, from_bus=bus67, to_bus=bus68, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line67")
line68 = pp.create_line(net, from_bus=bus68, to_bus=bus69, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line68")

# %%
#create motor

motor = pp.create_sgen(net, bus=bus3, p_mw=3, sn_mva=3.162 , k=1.2, q_mvar=1, rx=7, name="motor")

# %%
#create transformers

trafo1 = pp.create_transformer(net, hv_bus=bus1, lv_bus=bus2, std_type="25 MVA 110/20 kV", name="trafo1")
trafo2 = pp.create_transformer(net, hv_bus=bus4, lv_bus=bus41, std_type="0.4 MVA 20/0.4 kV", name="trafo2")
trafo3 = pp.create_transformer(net, hv_bus=bus5, lv_bus=bus51, std_type="0.4 MVA 20/0.4 kV", name="trafo3")
trafo4 = pp.create_transformer(net, hv_bus=bus6, lv_bus=bus61, std_type="0.4 MVA 20/0.4 kV", name="trafo4")

# %%
#create low loads 4

load1 = pp.create_load(net, bus=bus42, p_mw=0.0022, q_mvar=0.00072, name="load1")
load2 = pp.create_load(net, bus=bus43, p_mw=0.0022, q_mvar=0.00072, name="load2")
load3 = pp.create_load(net, bus=bus44, p_mw=0.0022, q_mvar=0.00072, name="load3")
load4 = pp.create_load(net, bus=bus45, p_mw=0.0022, q_mvar=0.00072, name="load4")
load5 = pp.create_load(net, bus=bus46, p_mw=0.0022, q_mvar=0.00072, name="load5")
load6 = pp.create_load(net, bus=bus47, p_mw=0.0022, q_mvar=0.00072, name="load6")
load7 = pp.create_load(net, bus=bus48, p_mw=0.0022, q_mvar=0.00072, name="load7")
load8 = pp.create_load(net, bus=bus49, p_mw=0.0022, q_mvar=0.00072, name="load8")

# %%
#create low loads 5

load9  = pp.create_load(net, bus=bus52, p_mw=0.0022, q_mvar=0.00072, name="load9")
load10 = pp.create_load(net, bus=bus53, p_mw=0.0022, q_mvar=0.00072, name="load10")
load11 = pp.create_load(net, bus=bus54, p_mw=0.0022, q_mvar=0.00072, name="load11")
load12 = pp.create_load(net, bus=bus55, p_mw=0.0022, q_mvar=0.00072, name="load12")
load13 = pp.create_load(net, bus=bus56, p_mw=0.0022, q_mvar=0.00072, name="load13")
load14 = pp.create_load(net, bus=bus57, p_mw=0.0022, q_mvar=0.00072, name="load14")
load15 = pp.create_load(net, bus=bus58, p_mw=0.0022, q_mvar=0.00072, name="load15")
load16 = pp.create_load(net, bus=bus59, p_mw=0.0022, q_mvar=0.00072, name="load16")

# %%
#create low loads 6

load17 = pp.create_load(net, bus=bus62, p_mw=0.0022, q_mvar=0.00072, name="load17")
load18 = pp.create_load(net, bus=bus63, p_mw=0.0022, q_mvar=0.00072, name="load18")
load19 = pp.create_load(net, bus=bus64, p_mw=0.0022, q_mvar=0.00072, name="load19")
load20 = pp.create_load(net, bus=bus65, p_mw=0.0022, q_mvar=0.00072, name="load20")
load21 = pp.create_load(net, bus=bus66, p_mw=0.0022, q_mvar=0.00072, name="load21")
load22 = pp.create_load(net, bus=bus67, p_mw=0.0022, q_mvar=0.00072, name="load22")
load23 = pp.create_load(net, bus=bus68, p_mw=0.0022, q_mvar=0.00072, name="load23")
load24 = pp.create_load(net, bus=bus69, p_mw=0.0022, q_mvar=0.00072, name="load24")

# %%
#pp.runpp(net)

# %%
print(net)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (33 elements)
#    - load (24 elements)
#    - sgen (1 element)
#    - ext_grid (1 element)
#    - line (28 elements)
#    - trafo (4 elements)

# %%
## 2.2 Tasks

# %% [markdown]
# ###1) Model the test system in pandapower2
# .
# a. What is the type of the 20 kV lines used?
#
# -> 20kv lines are used to transport electricity between cities.
#
# What information can you find from manufacturers?
#
# -> Construction:
#     stranded aluminium wire, inner layer of semi-conducting material,
#     core insullation of cross-linked polyethylene, outer layer of semi-conducting material
#     swellable tape, screen of copper wires, anti-twist tape,  outer sheath of polyethylene
#
# -> Resistance = 0.313 ohm, Diameter 95 mm^2
#
# Is this typical for MV systems?
#
# -> Yes, maybe in future we will see that lines isolated underground, but for now, is the best sollution out there.
#
# b. What is the type of the 400 V lines used?
#
# What information can you find from manufacturers?
#
# -> Resistance = 0,595 ohm, Diameter 48,25 mm^2
#
# Is this typical for LV systems?
#
# -> Yes, this is typical for low voltage networks.
#
# c. Is this a radial or meshed system? Is this typical for distribution networks?
# Why?
#
.027226  0.027226  0.027226    1.006640        0.610264  0.998882
# 21   0.023881  0.023881  0.023881    0.998882        0.544044  0.992078
# 22   0.020513  0.020513  0.020513    0.992078        0.485251  0.986234
# 23   0.017126  0.017126  0.017126    0.986234        0.434212  0.981355
# 24   0.013721  0.013721  0.013721    0.981355        0.391214  0.977446
# 25   0.010303  0.010303  0.010303    0.977446        0.356506  0.974512
# 26   0.006874  0.006874  0.006874    0.974512        0.330293  0.972554
# 27   0.003439  0.003439  0.003439    0.972554        0.312730  0.971574
#
#     va_to_degree  loading_percent
# 0       0.816950        35.997896
# 1       0.752150         1.825623
# 2       0.744143         2.137163
# 3       0.752150         1.825623
# 4       0.544044        12.964812
# 5       0.485251        11.372023
# 6       0.434212         9.768307
# 7       0.391214         8.155086
# 8       0.356506         6.533844
# 9       0.330293         4.906118
# 10      0.312730         3.273491
# 11      0.303922         1.637576
# 12      0.536054        12.964247
# 13      0.477267        11.371525
# 14      0.426231         9.767878
# 15      0.383237         8.154726
# 16      0.348533         6.533555
# 17      0.322322         4.905901
# 18      0.304760         3.273345
# 19      0.295953         1.637504
# 20      0.544044        12.964812
# 21      0.485251        11.372023
# 22      0.434212         9.768307
# 23      0.391214         8.155086
# 24      0.356506         6.533844
# 25      0.330293         4.906118
# 26      0.312730         3.273491
# 27      0.303922         1.637576

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0 -2.887723  -1.567084  2.903616   1.629728  0.015892  0.062644  0.017245
# 1  0.019408   0.006029 -0.018024  -0.005974  0.001384  0.000056  0.000582
# 2  0.019408   0.006029 -0.018024  -0.005974  0.001384  0.000056  0.000582
# 3  0.019408   0.006029 -0.018024  -0.005974  0.001384  0.000056  0.000582
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.095347  1.000000      0.000000  1.008110      0.774626        13.211717
# 1  0.027226  1.008170      0.752150  1.006640      0.610264         5.039442
# 2  0.027225  1.008211      0.744143  1.006682      0.602268         5.039250
# 3  0.027226  1.008170      0.752150  1.006640      0.610264         5.039442

# %% [markdown]
# 2)a. Are there any violations of voltage, line, or transformers?
#
# -> No.
#
# b. Create and display a colormap of the buses showing blue for all voltages below 0.95, green for voltages between 0.95 and 1.05, and red for all voltages above 1.05 pu.

# %%
from pandapower.plotting.plotly import pf_res_plotly
import pandapower.plotting.plotly
pp.runpp(net)
pf_res_plotly(net)

# %%
import pandapower.plotting as plot
pp.runpp(net)
cmap_list=[((0,0.95), "blue"),((0.95,1.05), "green"),((1.05,1.1), "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc=create_line_collection(net)
plot.draw_collections([lc,bc])

# %% [markdown]
# 3) Consider that the power consumption of every household is increased to 4 kW at 0.95
# power factor and solve the power flow.

# %%
#create new loads
load1 = pp.create_load(net, bus=bus42, p_mw=0.005, q_mvar=0.00164, name="load1")
load2 = pp.create_load(net, bus=bus43, p_mw=0.005, q_mvar=0.00164, name="load2")
load3 = pp.create_load(net, bus=bus44, p_mw=0.005, q_mvar=0.00164, name="load3")
load4 = pp.create_load(net, bus=bus45, p_mw=0.005, q_mvar=0.00164, name="load4")
load5 = pp.create_load(net, bus=bus46, p_mw=0.005, q_mvar=0.00164, name="load5")
load6 = pp.create_load(net, bus=bus47, p_mw=0.005, q_mvar=0.00164, name="load6")
load7 = pp.create_load(net, bus=bus48, p_mw=0.005, q_mvar=0.00164, name="load7")
load8 = pp.create_load(net, bus=bus49, p_mw=0.005, q_mvar=0.00164, name="load8")

load9  = pp.create_load(net, bus=bus52, p_mw=0.005, q_mvar=0.00164, name="load9")
load10 = pp.create_load(net, bus=bus53, p_mw=0.005, q_mvar=0.00164, name="load10")
load11 = pp.create_load(net, bus=bus54, p_mw=0.005, q_mvar=0.00164, name="load11")
load12 = pp.create_load(net, bus=bus55, p_mw=0.005, q_mvar=0.00164, name="load12")
load13 = pp.create_load(net, bus=bus56, p_mw=0.005, q_mvar=0.00164, name="load13")
load14 = pp.create_load(net, bus=bus57, p_mw=0.005, q_mvar=0.00164, name="load14")
load15 = pp.create_load(net, bus=bus58, p_mw=0.005, q_mvar=0.00164, name="load15")
load16 = pp.create_load(net, bus=bus59, p_mw=0.005, q_mvar=0.00164, name="load16")
 
load17 = pp.create_load(net, bus=bus62, p_mw=0.005, q_mvar=0.00164, name="load17")
load18 = pp.create_load(net, bus=bus63, p_mw=0.005, q_mvar=0.00164, name="load18")
load19 = pp.create_load(net, bus=bus64, p_mw=0.005, q_mvar=0.00164, name="load19")
load20 = pp.create_load(net, bus=bus65, p_mw=0.005, q_mvar=0.00164, name="load20")
load21 = pp.create_load(net, bus=bus66, p_mw=0.005, q_mvar=0.00164, name="load21")
load22 = pp.create_load(net, bus=bus67, p_mw=0.005, q_mvar=0.00164, name="load22")
load23 = pp.create_load(net, bus=bus68, p_mw=0.005, q_mvar=0.00164, name="load23")
load24 = pp.create_load(net, bus=bus69, p_mw=0.005, q_mvar=0.00164, name="load24")

# %%
pp.runpp(net)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.887723  1.567084
# 1   1.008110   0.774626  0.000000  0.000000
# 2   1.021332   0.816950 -3.000000 -1.000000
# 3   1.008170   0.752150  0.000000  0.000000
# 4   1.008211   0.744143  0.000000  0.000000
# 5   1.008170   0.752150  0.000000  0.000000
# 6   1.006640   0.610264  0.000000  0.000000
# 7   0.998882   0.544044  0.002200  0.000720
# 8   0.992078   0.485251  0.002200  0.000720
# 9   0.986234   0.434212  0.002200  0.000720
# 10  0.981355   0.391214  0.002200  0.000720
# 11  0.977446   0.356506  0.002200  0.000720
# 12  0.974512   0.330293  0.002200  0.000720
# 13  0.972554   0.312730  0.002200  0.000720
# 14  0.971574   0.303922  0.002200  0.000720
# 15  1.006682   0.602268  0.000000  0.000000
# 16  0.998924   0.536054  0.002200  0.000720
# 17  0.992120   0.477267  0.002200  0.000720
# 18  0.986276   0.426231  0.002200  0.000720
# 19  0.981398   0.383237  0.002200  0.000720
# 20  0.977489   0.348533  0.002200  0.000720
# 21  0.974555   0.322322  0.002200  0.000720
# 22  0.972597   0.304760  0.002200  0.000720
# 23  0.971618   0.295953  0.002200  0.000720
# 24  1.006640   0.610264  0.000000  0.000000
# 25  0.998882   0.544044  0.002200  0.000720
# 26  0.992078   0.485251  0.002200  0.000720
# 27  0.986234   0.434212  0.002200  0.000720
# 28  0.981355   0.391214  0.002200  0.000720
# 29  0.977446   0.356506  0.002200  0.000720
# 30  0.974512   0.330293  0.002200  0.000720
# 31  0.972554   0.312730  0.002200  0.000720
# 32  0.971574   0.303922  0.002200  0.000720

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar
0.027226  1.008170      0.752150  1.006640      0.610264         5.039442

# %% [markdown]
# 3)a. Are there any violations of voltage, line, or transformers?
#
# -> No.

# %% [markdown]
# 3)b. Create and display a colormap of the buses showing blue for all voltages below 0.95, green for voltages between 0.95 and 1.05, and red for all voltages above 1.05 pu.

# %%
from pandapower.plotting.plotly import pf_res_plotly
import pandapower.plotting.plotly
pp.runpp(net)
pf_res_plotly(net)

# %%
import pandapower.plotting as plot
pp.runpp(net)
cmap_list=[((0,0.95), "blue"),((0.95,1.05), "green"),((1.05,1.1), "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc=create_line_collection(net)
plot.draw_collections([lc,bc])

# %% [markdown]
# 4) If we consider that each house will purchase an electric vehicle with a 7 kW charger (in
# addition to their normal 2 kW with PF=0.95 load) and they want to charge at the same
# time

# %%
#create new loads
load1 = pp.create_load(net, bus=bus42, p_mw=0.005, q_mvar=0.00164, name="load1")
load2 = pp.create_load(net, bus=bus43, p_mw=0.005, q_mvar=0.00164, name="load2")
load3 = pp.create_load(net, bus=bus44, p_mw=0.005, q_mvar=0.00164, name="load3")
load4 = pp.create_load(net, bus=bus45, p_mw=0.005, q_mvar=0.00164, name="load4")
load5 = pp.create_load(net, bus=bus46, p_mw=0.005, q_mvar=0.00164, name="load5")
load6 = pp.create_load(net, bus=bus47, p_mw=0.005, q_mvar=0.00164, name="load6")
load7 = pp.create_load(net, bus=bus48, p_mw=0.005, q_mvar=0.00164, name="load7")
load8 = pp.create_load(net, bus=bus49, p_mw=0.005, q_mvar=0.00164, name="load8")

load9  = pp.create_load(net, bus=bus52, p_mw=0.005, q_mvar=0.00164, name="load9")
load10 = pp.create_load(net, bus=bus53, p_mw=0.005, q_mvar=0.00164, name="load10")
load11 = pp.create_load(net, bus=bus54, p_mw=0.005, q_mvar=0.00164, name="load11")
load12 = pp.create_load(net, bus=bus55, p_mw=0.005, q_mvar=0.00164, name="load12")
load13 = pp.create_load(net, bus=bus56, p_mw=0.005, q_mvar=0.00164, name="load13")
load14 = pp.create_load(net, bus=bus57, p_mw=0.005, q_mvar=0.00164, name="load14")
load15 = pp.create_load(net, bus=bus58, p_mw=0.005, q_mvar=0.00164, name="load15")
load16 = pp.create_load(net, bus=bus59, p_mw=0.005, q_mvar=0.00164, name="load16")

load17 = pp.create_load(net, bus=bus62, p_mw=0.005, q_mvar=0.00164, name="load17")
load18 = pp.create_load(net, bus=bus63, p_mw=0.005, q_mvar=0.00164, name="load18")
load19 = pp.create_load(net, bus=bus64, p_mw=0.005, q_mvar=0.00164, name="load19")
load20 = pp.create_load(net, bus=bus65, p_mw=0.005, q_mvar=0.00164, name="load20")
load21 = pp.create_load(net, bus=bus66, p_mw=0.005, q_mvar=0.00164, name="load21")
load22 = pp.create_load(net, bus=bus67, p_mw=0.005, q_mvar=0.00164, name="load22")
load23 = pp.create_load(net, bus=bus68, p_mw=0.005, q_mvar=0.00164, name="load23")
load24 = pp.create_load(net, bus=bus69, p_mw=0.005, q_mvar=0.00164, name="load24")

# %%
pp.runpp(net)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.887723  1.567084
# 1   1.008110   0.774626  0.000000  0.000000
0.003439  0.003439  0.003439    0.972554        0.312730  0.971574
# 12   0.027225  0.027225  0.027225    1.006682        0.602268  0.998924
# 13   0.023880  0.023880  0.023880    0.998924        0.536054  0.992120
# 14   0.020513  0.020513  0.020513    0.992120        0.477267  0.986276
# 15   0.017125  0.017125  0.017125    0.986276        0.426231  0.981398
# 16   0.013720  0.013720  0.013720    0.981398        0.383237  0.977489
# 17   0.010302  0.010302  0.010302    0.977489        0.348533  0.974555
# 18   0.006874  0.006874  0.006874    0.974555        0.322322  0.972597
# 19   0.003439  0.003439  0.003439    0.972597        0.304760  0.971618
# 20   0.027226  0.027226  0.027226    1.006640        0.610264  0.998882
# 21   0.023881  0.023881  0.023881    0.998882        0.544044  0.992078
# 22   0.020513  0.020513  0.020513    0.992078        0.485251  0.986234
# 23   0.017126  0.017126  0.017126    0.986234        0.434212  0.981355
# 24   0.013721  0.013721  0.013721    0.981355        0.391214  0.977446
# 25   0.010303  0.010303  0.010303    0.977446        0.356506  0.974512
# 26   0.006874  0.006874  0.006874    0.974512        0.330293  0.972554
# 27   0.003439  0.003439  0.003439    0.972554        0.312730  0.971574
#
#     va_to_degree  loading_percent
# 0       0.816950        35.997896
# 1       0.752150         1.825623
# 2       0.744143         2.137163
# 3       0.752150         1.825623
# 4       0.544044        12.964812
# 5       0.485251        11.372023
# 6       0.434212         9.768307
# 7       0.391214         8.155086
# 8       0.356506         6.533844
# 9       0.330293         4.906118
# 10      0.312730         3.273491
# 11      0.303922         1.637576
# 12      0.536054        12.964247
# 13      0.477267        11.371525
# 14      0.426231         9.767878
# 15      0.383237         8.154726
# 16      0.348533         6.533555
# 17      0.322322         4.905901
# 18      0.304760         3.273345
# 19      0.295953         1.637504
# 20      0.544044        12.964812
# 21      0.485251        11.372023
# 22      0.434212         9.768307
# 23      0.391214         8.155086
# 24      0.356506         6.533844
# 25      0.330293         4.906118
# 26      0.312730         3.273491
# 27      0.303922         1.637576

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0 -2.887723  -1.567084  2.903616   1.629728  0.015892  0.062644  0.017245
# 1  0.019408   0.006029 -0.018024  -0.005974  0.001384  0.000056  0.000582
# 2  0.019408   0.006029 -0.018024  -0.005974  0.001384  0.000056  0.000582
# 3  0.019408   0.006029 -0.018024  -0.005974  0.001384  0.000056  0.000582
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.095347  1.000000      0.000000  1.008110      0.774626        13.211717
# 1  0.027226  1.008170      0.752150  1.006640      0.610264         5.039442
# 2  0.027225  1.008211      0.744143  1.006682      0.602268         5.039250
# 3  0.027226  1.008170      0.752150  1.006640      0.610264         5.039442

# %%
from pandapower.plotting.plotly import pf_res_plotly
import pandapower.plotting.plotly
pp.runpp(net)
pf_res_plotly(net)

# %% [markdown]
# 4)a. Is the system able to withstand this load?
#
# -> Yes. As far as I know, we can get somewhere under 10 kW from the network, with the usual single-phase system. if other large consumers are turned on at home at the same time, of course your network can enter in safe mode and turn off the power.

# %%
4)b. If no, propose some solutions to alleviate the problem.

-> The best solution from the owners would be to install a three-phase system, which can provide up to 40kW

# %%
##3.1 Short circuit analysis

# %% [markdown]
# 3.1 Tasks
# 1) Compute the maximum three-phase short-circuit currents for a solid fault (ZF=0 Ω).

# %% [markdown]
# 1)a. Present the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, ip=True, ith=True, branch_results=True)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka     skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.544779  100.000000   1.039833  0.547460  43.969642  125.627547
# 1   2.154304   70.832867   4.435416  2.168940   1.517492    6.023599
# 2   1.835268   59.781143   3.243817  1.842178   3.082492    6.683599
# 3   1.757434   57.783918   3.051211  1.763578   3.395492    6.815599
# 4   1.699228   55.870123   2.899378  1.704790   3.708492    6.947599
# 5   1.757434   57.783918   3.051211  1.763578   3.395492    6.815599
# 6   9.835564    6.467809  19.915061  9.897797   0.007113    0.026265
# 7   3.072391    2.020386   4.544073  3.077455   0.066503    0.056265
# 8   1.753726    1.153240   2.556174  1.756279   0.125893    0.086265
# 9   1.223558    0.804605   1.776722  1.225272   0.185283    0.116265
# 10  0.938901    0.617416   1.361183  0.940193   0.244673    0.146265
# 11  0.761516    0.500768   1.103055  0.762553   0.304063    0.176265
# 12  0.640440    0.421149   0.927175  0.641307   0.363453    0.206265
# 13  0.552553    0.363356   0.799648  0.553298   0.422843    0.236265
# 14  0.485863    0.319501   0.702950  0.486516   0.482233    0.266265
# 15  9.805331    6.447927  19.781943  9.866438   0.007239    0.026318
# 16  3.067824    2.017383   4.536929  3.072877   0.066629    0.056318
# 17  1.752197    1.152235   2.553898  1.754747   0.126019    0.086318
# 18  1.222808    0.804112   1.775619  1.224521   0.185409    0.116318
# 19  0.938458    0.617125   1.360534  0.939749   0.244799    0.146318
# 20  0.761224    0.500576   1.102629  0.762261   0.304189    0.176318
# 21  0.640233    0.421013   0.926874  0.641100   0.363579    0.206318
# 22  0.552399    0.363254   0.799424  0.553144   0.422969    0.236318
# 23  0.485744    0.319422   0.702776  0.486397   0.482359    0.266318
# 24  9.835564    6.467809  19.915061  9.897797   0.007113    0.026265
# 25  3.072391    2.020386   4.544073  3.077455   0.066503    0.056265
# 26  1.753726    1.153240   2.556174  1.756279   0.125893    0.086265
# 27  1.223558    0.804605   1.776722  1.225272   0.185283    0.116265
# 28  0.938901    0.617416   1.361183  0.940193   0.244673    0.146265
# 29  0.761516    0.500768   1.103055  0.762553   0.304063    0.176265
# 30  0.640440    0.421149   0.927175  0.641307   0.363453    0.206265
# 31  0.552553    0.363356   0.799648  0.553298   0.422843    0.236265
# 32  0.485863    0.319501   0.702950  0.486516   0.482233    0.266265

# %% [markdown]
# 1)b. Present the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
net.res_trafo_sc

# %% [markdown]
# 1)c. What is the difference between the three values of current computed at each
# node or line?
#
# -> The difference between the three values of current computed is not that high.

# %% [markdown]
# 1)d. Which standard is used to compute the short-circuit currents?
#
# -> standard used to compute the short-circuit currents is: DIN/IEC EN 60909.
#
# Briefly explain the methodology based on the documentation, the slides of the course, and material you find online.
#
# -> The short-circuit currents in three-phase systems can be determined by three different calculation procedures:
#
# 1. superposition method for a defined load flow case
#
# The superposition method is an exact method for the calculation of the shortcircuit currents. The method consists of three steps. The calculation considers the impedances, power supply feeders, and node loads of the active elements. In the second step, the voltage applied to the fault location before the occurrence of the short circuit and the current distribution at the fault location are determined with a negative sign. . In the third step, both the conditions are superimposed. We then obtain a zero voltage at the fault location. The superposition of the currents also leads to the value zero. The disadvantage of this method is that the steady-state condition must be specified.
#
# 2. Calculating with the equivalent voltage source at the fault location method following conditions:
#
# a) The passive loads and conductor capacitances can be neglected
# b) The step setting of the transformers need not be considered
# c) The excitation of the generators need not be considered
# d) The time and position dependence of the previous load (loading state) of the network need not be considered.
#
# 3. Transient Calculation method
# With the transient method, the individual operating equipment and, as a result, the entire network are represented by a system of differential equations. The calculation is very tedious. The method with the equivalent voltage source is a simplification relative to the other methods. Since 1988, it has been standardized internationally in IEC 60909-0. The calculation is independent of a current operational state. Therefore, in this book, the method with the equivalent voltage source will be dealt with and discussed.

# %% [markdown]
# 2) Deactivate the contribution of the large motor4 and re-compute the maximum threephase short-circuit currents for a solid fault (ZF=0 Ω).

# %%
net.sgen.in_service=False

# %% [markdown]
# 2)a. a. Present the initial symmetrical short-circuit current, the short-circuit current peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, ip=True, ith=True, branch_results=True)
net.res_bus_sc

# %% [markdown]
# 2)b. Present the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc

# %%
net.res_trafo_sc

# %% [markdown]
# 2)c. Compare to the values of Task 1 and explain the difference.

# %%
net.sgen.in_service=True

# %% [markdown]
# 3) Compute the maximum three-phase short-circuit currents with fault impedance
# ZF=1+j1.5 Ω.

# %% [markdown]
# 3)a. Present the initial symmetrical short-circuit current, the short-circuit current peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, ip=True, ith=True, branch_results=True, r_fault_ohm=1, x_fault_ohm=1.5)
net.res_bus_sc

# %% [markdown]
# 3)b. Present the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc

# %%
net.res_trafo_sc

# %% [markdown]
# 3)c. Compare to the values of Task 1 and explain the difference.

# %% [markdown]
# 4) Compute the maximum two-phase short-circuit currents for a solid fault (ZF=0 Ω).

# %% [markdown]
# 4)a. Present the initial symmetrical short-circuit current, the short-circuit current peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, fault="2ph", ip=True, ith=True, branch_results=True)
net.res_bus_s

# %% [markdown]
# 4)b. Present the initial symmetrical short-circuit current, the short-circuit current peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc

# %%
net.res_trafo_sc

# %%
4)c. Compare to the values of Task 1 and explain the difference.
