# %%
import pandapower as pp

#create empty net
net = pp.create_empty_network()

# %%
#create buses
bus1 = pp.create_bus(net, vn_kv=110, name="Bus 1")
bus2 = pp.create_bus(net, vn_kv=20, name="Bus 2")
bus3 = pp.create_bus(net, vn_kv=20, name="Bus 3")
bus4 = pp.create_bus(net, vn_kv=20, name="Bus 4")
bus5 = pp.create_bus(net, vn_kv=20, name="Bus 5")
bus6 = pp.create_bus(net, vn_kv=20, name="Bus 6")

bus41 = pp.create_bus(net, vn_kv=0.4, name="Bus 41")
bus42 = pp.create_bus(net, vn_kv=0.4, name="Bus 42")
bus43 = pp.create_bus(net, vn_kv=0.4, name="Bus 43")
bus44 = pp.create_bus(net, vn_kv=0.4, name="Bus 44")
bus45 = pp.create_bus(net, vn_kv=0.4, name="Bus 45")
bus46 = pp.create_bus(net, vn_kv=0.4, name="Bus 46")
bus47 = pp.create_bus(net, vn_kv=0.4, name="Bus 47")
bus48 = pp.create_bus(net, vn_kv=0.4, name="Bus 48")
bus49 = pp.create_bus(net, vn_kv=0.4, name="Bus 49")

bus51 = pp.create_bus(net, vn_kv=0.4, name="Bus 51")
bus52 = pp.create_bus(net, vn_kv=0.4, name="Bus 52")
bus53 = pp.create_bus(net, vn_kv=0.4, name="Bus 53")
bus54 = pp.create_bus(net, vn_kv=0.4, name="Bus 54")
bus55 = pp.create_bus(net, vn_kv=0.4, name="Bus 55")
bus56 = pp.create_bus(net, vn_kv=0.4, name="Bus 56")
bus57 = pp.create_bus(net, vn_kv=0.4, name="Bus 57")
bus58 = pp.create_bus(net, vn_kv=0.4, name="Bus 58")
bus59 = pp.create_bus(net, vn_kv=0.4, name="Bus 59")

bus61 = pp.create_bus(net, vn_kv=0.4, name="Bus 61")
bus62 = pp.create_bus(net, vn_kv=0.4, name="Bus 62")
bus63 = pp.create_bus(net, vn_kv=0.4, name="Bus 63")
bus64 = pp.create_bus(net, vn_kv=0.4, name="Bus 64")
bus65 = pp.create_bus(net, vn_kv=0.4, name="Bus 65")
bus66 = pp.create_bus(net, vn_kv=0.4, name="Bus 66")
bus67 = pp.create_bus(net, vn_kv=0.4, name="Bus 67")
bus68 = pp.create_bus(net, vn_kv=0.4, name="Bus 68")
bus69 = pp.create_bus(net, vn_kv=0.4, name="Bus 69")

# %%
#create external grid
grid=pp.create_ext_grid(net, bus=bus1, s_sc_max_mva=100, s_sc_min_mva=80, rx_min=0.2, rx_max=0.35)

# %%
#create lines
line1 = pp.create_line(net, from_bus=bus2, to_bus=bus3, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=5, name="line1")
line2 = pp.create_line(net, from_bus=bus2, to_bus=bus4, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=6, name="line2")
line3 = pp.create_line(net, from_bus=bus2, to_bus=bus5, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=7, name="line3")
line4 = pp.create_line(net, from_bus=bus2, to_bus=bus6, std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=6, name="line4")

line41 = pp.create_line(net, from_bus=bus41, to_bus=bus42, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line41")
line42 = pp.create_line(net, from_bus=bus42, to_bus=bus43, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line42")
line43 = pp.create_line(net, from_bus=bus43, to_bus=bus44, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line43")
line44 = pp.create_line(net, from_bus=bus44, to_bus=bus45, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line44")
line45 = pp.create_line(net, from_bus=bus45, to_bus=bus46, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line45")
line46 = pp.create_line(net, from_bus=bus46, to_bus=bus47, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line46")
line47 = pp.create_line(net, from_bus=bus47, to_bus=bus48, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line47")
line48 = pp.create_line(net, from_bus=bus48, to_bus=bus49, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line48")

line51 = pp.create_line(net, from_bus=bus51, to_bus=bus52, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line51")
line52 = pp.create_line(net, from_bus=bus52, to_bus=bus53, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line52")
line53 = pp.create_line(net, from_bus=bus53, to_bus=bus54, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line53")
line54 = pp.create_line(net, from_bus=bus54, to_bus=bus55, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line54")
line55 = pp.create_line(net, from_bus=bus55, to_bus=bus56, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line55")
line56 = pp.create_line(net, from_bus=bus56, to_bus=bus57, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line56")
line57 = pp.create_line(net, from_bus=bus57, to_bus=bus58, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line57")
line58 = pp.create_line(net, from_bus=bus58, to_bus=bus59, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line58")

line61 = pp.create_line(net, from_bus=bus61, to_bus=bus62, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line61")
line62 = pp.create_line(net, from_bus=bus62, to_bus=bus63, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line62")
line63 = pp.create_line(net, from_bus=bus63, to_bus=bus64, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line63")
line64 = pp.create_line(net, from_bus=bus64, to_bus=bus65, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line64")
line65 = pp.create_line(net, from_bus=bus65, to_bus=bus66, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line65")
line66 = pp.create_line(net, from_bus=bus66, to_bus=bus67, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line66")
line67 = pp.create_line(net, from_bus=bus67, to_bus=bus68, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line67")
line68 = pp.create_line(net, from_bus=bus68, to_bus=bus69, length_km=0.1, std_type="48-AL1/8-ST1A 0.4", name="line68")

# %%
#create transformers
trafo1 = pp.create_transformer(net, hv_bus=bus1, lv_bus=bus2, std_type="25 MVA 110/20 kV", name="trafo1")
trafo2 = pp.create_transformer(net, hv_bus=bus4, lv_bus=bus41, std_type="0.4 MVA 20/0.4 kV", name="trafo2")
trafo3 = pp.create_transformer(net, hv_bus=bus5, lv_bus=bus51, std_type="0.4 MVA 20/0.4 kV", name="trafo3")
trafo4 = pp.create_transformer(net, hv_bus=bus6, lv_bus=bus61, std_type="0.4 MVA 20/0.4 kV", name="trafo4")

# %%
#create motor
motor = pp.create_sgen(net, bus=bus3, p_mw=3, sn_mva=3.162 , k=1.2, q_mvar=1, rx=7, name="motor")

# %%
#create load
load1=pp.create_load(net, bus=bus42, p_mw=0.0022, q_mvar=0.00072, name="load1")
load2=pp.create_load(net, bus=bus43, p_mw=0.0022, q_mvar=0.00072, name="load2")
load3=pp.create_load(net, bus=bus44, p_mw=0.0022, q_mvar=0.00072, name="load3")
load4=pp.create_load(net, bus=bus45, p_mw=0.0022, q_mvar=0.00072, name="load4")
load5=pp.create_load(net, bus=bus46, p_mw=0.0022, q_mvar=0.00072, name="load5")
load6=pp.create_load(net, bus=bus47, p_mw=0.0022, q_mvar=0.00072, name="load6")
load7=pp.create_load(net, bus=bus48, p_mw=0.0022, q_mvar=0.00072, name="load7")
load8=pp.create_load(net, bus=bus49, p_mw=0.0022, q_mvar=0.00072, name="load8")

load9=pp.create_load(net, bus=bus52, p_mw=0.0022, q_mvar=0.00072, name="load9")
load10=pp.create_load(net, bus=bus53, p_mw=0.0022, q_mvar=0.00072, name="load10")
load11=pp.create_load(net, bus=bus54, p_mw=0.0022, q_mvar=0.00072, name="load11")
load12=pp.create_load(net, bus=bus55, p_mw=0.0022, q_mvar=0.00072, name="load12")
load13=pp.create_load(net, bus=bus56, p_mw=0.0022, q_mvar=0.00072, name="load13")
load14=pp.create_load(net, bus=bus57, p_mw=0.0022, q_mvar=0.00072, name="load14")
load15=pp.create_load(net, bus=bus58, p_mw=0.0022, q_mvar=0.00072, name="load15")
load16=pp.create_load(net, bus=bus59, p_mw=0.0022, q_mvar=0.00072, name="load16")

load17=pp.create_load(net, bus=bus62, p_mw=0.0022, q_mvar=0.00072, name="load17")
load18=pp.create_load(net, bus=bus63, p_mw=0.0022, q_mvar=0.00072, name="load18")
load19=pp.create_load(net, bus=bus64, p_mw=0.0022, q_mvar=0.00072, name="load19")
load20=pp.create_load(net, bus=bus65, p_mw=0.0022, q_mvar=0.00072, name="load20")
load21=pp.create_load(net, bus=bus66, p_mw=0.0022, q_mvar=0.00072, name="load21")
load22=pp.create_load(net, bus=bus67, p_mw=0.0022, q_mvar=0.00072, name="load22")
load23=pp.create_load(net, bus=bus68, p_mw=0.0022, q_mvar=0.00072, name="load23")
load24=pp.create_load(net, bus=bus69, p_mw=0.0022, q_mvar=0.00072, name="load24")

# %% [markdown]
# ## Power flow modelling and analysis
# ### 2.2 Tasks
#
# 1) Model the test system in pandapower
#
#    a. What is the type of the 20 kV lines used? What information can you find from
#       manufacturers? Is this typical for MV systems?
#
#       Standard type line NA2XS2Y 1x95 RM/25 12/20 kV
#
#       The information of line from manufacturers are listed below:
#       1. Resistance/km = 0.313 ohms
#       2. Reactance/km = 0.132 ohms
#       3. Capacitance/km = 216.0 nf
#       4. Maximum current = 0.252 KA
#       5. Type = cs
#       6. Diameter = 95mm2
#       7. Alpha = 0.00403
#
#       Yes, These type of lines are usually used for Medium Voltage systems as their ratings and parameters are suitable.
#
#    b. What is the type of the 400 V lines used? What information can you find from
#       manufacturers? Is this typical for LV systems?
#
#       Standard type line 48-AL1/8-ST1A 0.4
#
#       The information of line from manufacturers are listed below:
#       1. Resistance/km = 0.5939 ohms
#       2. Reactance/km = 0.3 ohms
#       3. Capacitance/km = 12.2 nf
#       4. Maximum current = 0.21 KA
#       5. Type = ol
#       6. Diameter = 48mm2
#       7. Alpha = 0.00403
#
#       Yes, These type of lines are usually used for Low Voltage systems as their ratings and parameters are suitable.
#
#     c. Is this a radial or meshed system? Is this typical for distribution networks? Why?
#
#        It is a radial system.
#        Yes, It's typically used in distribution networks with household loads but that mainly depends on the type of load.
#        As the commercial and industrial loads need continuous power supply meshed system is used so that we can send the
#        power in different path in case of a fault in the system.

# %% [markdown]
# 2) Run a power flow and display all the bus voltages, line currents, and transformer loadings.

# %%
pp.runpp(net)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.293884  1.328123
# 1   1.006832   0.615710  0.000000  0.000000
# 2   1.020070   0.658178 -3.000000 -1.000000
# 3   1.005801   0.593618  0.000000  0.000000
# 4   1.005659   0.585692  0.000000  0.000000
# 5   1.005801   0.593618  0.000000  0.000000
# 6   0.985371  -1.044193  0.000000  0.000000
# 7   0.889030  -1.656072  0.017600  0.005740
# 8   0.801356  -2.314409  0.017600  0.005740
# 9   0.723290  -3.008004  0.017600  0.005740
# 10  0.655852  -3.714232  0.017600  0.005740
# 11  0.600114  -4.395178  0.017600  0.005740
# 12  0.557132  -4.996379  0.017600  0.005740
# 13  0.527857  -5.452040  0.017600  0.005740
# 14  0.513020  -5.699458  0.017600  0.005740
# 15  0.985211  -1.053637  0.000000  0.000000
# 16  0.888788  -1.665782  0.017600  0.005740
# 17  0.801036  -2.324562  0.017600  0.005740
# 18  0.722895  -3.018815  0.017600  0.005740
# 19  0.655388  -3.725929  0.017600  0.005740
# ...

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  \
# 0   -2.961850    -1.123309  3.000000   1.000000  0.038150 -0.123309
# 1    0.217511    -0.073983 -0.217292  -0.090848  0.000219 -0.164832
# 2    0.217689    -0.101345 -0.217433  -0.090931  0.000256 -0.192276
# 3    0.217511    -0.073983 -0.217292  -0.090848  0.000219 -0.164832
# 4    0.214011     0.082901 -0.193874  -0.072730  0.020136  0.010172
# 5    0.176274     0.066990 -0.159574  -0.058554  0.016700  0.008436
# 6    0.141974     0.052814 -0.128711  -0.046114  0.013263  0.006700
# 7    0.111111     0.040374 -0.101195  -0.035365  0.009916  0.005009
# 8    0.083595     0.029625 -0.076807  -0.026196  0.006788  0.003429
# 9    0.059207     0.020456 -0.055163  -0.018413  0.004044  0.002043
# 10   0.037563     0.012673 -0.035683  -0.011724  0.001879  0.000949
# 11   0.018083     0.005984 -0.017600  -0.005740  0.000483  0.000244
# 12   0.214149     0.082971 -0.193979  -0.072782  0.020170  0.010189
# ...

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0 -2.293884  -1.328123  2.309139   1.372622  0.015255  0.044498  0.013912
# 1  0.217292   0.090848 -0.214011  -0.082901  0.003281  0.007947  0.006760
# 2  0.217433   0.090931 -0.214149  -0.082971  0.003284  0.007960  0.006765
# 3  0.217292   0.090848 -0.214011  -0.082901  0.003281  0.007947  0.006760
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.077021  1.000000      0.000000  1.006832      0.615710        10.672292
# 1  0.336182  1.005801      0.593618  0.985371     -1.044193        58.540056
# 2  0.336463  1.005659      0.585692  0.985211     -1.053637        58.588632
# 3  0.336182  1.005801      0.593618  0.985371     -1.044193        58.540056

# %%
from pandapower.plotting.plotly import pf_res_plotly
import pandapower.plotting.plotly
pp.runpp(net)
pf_res_plotly(net)

# %% [markdown]
#
#    a. Are there any violations of voltage, line, or transformers?
#
#       No, There are no violations of voltage, line and tranformers.
#
#    b. Create and display a colormap of the buses showing blue for all voltages below 0.95, green for voltages between 0.95
#       and 1.05, and red for all voltages above 1.05 pu.

# %%
import pandapower.plotting as plot
pp.runpp(net)
cmap_list=[((0,0.95), "blue"),((0.95,1.05) "green"),((1.05,1.1) "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc=create_line_collection(net)
plot.draw_collections([lc,bc])

# %% [markdown]
# 3) Consider that the power consumption of every household is increased to 4 kW at 0.95
#    power factor and solve the power flow

# %%
#create load
load1=pp.create_load(net, bus=bus42, p_mw=0.0018, q_mvar=0.00058, name="load1")
load2=pp.create_load(net, bus=bus43, p_mw=0.0018, q_mvar=0.00058, name="load2")
load3=pp.create_load(net, bus=bus44, p_mw=0.0018, q_mvar=0.00058, name="load3")
load4=pp.create_load(net, bus=bus45, p_mw=0.0018, q_mvar=0.00058, name="load4")
load5=pp.create_load(net, bus=bus46, p_mw=0.0018, q_mvar=0.00058, name="load5")
load6=pp.create_load(net, bus=bus47, p_mw=0.0018, q_mvar=0.00058, name="load6")
load7=pp.create_load(net, bus=bus48, p_mw=0.0018, q_mvar=0.00058, name="load7")
load8=pp.create_load(net, bus=bus49, p_mw=0.0018, q_mvar=0.00058, name="load8")

load9=pp.create_load(net, bus=bus52, p_mw=0.0018, q_mvar=0.00058, name="load9")
load10=pp.create_load(net, bus=bus53, p_mw=0.0018, q_mvar=0.00058, name="load10")
load11=pp.create_load(net, bus=bus54, p_mw=0.0018, q_mvar=0.00058, name="load11")
load12=pp.create_load(net, bus=bus55, p_mw=0.0018, q_mvar=0.00058, name="load12")
load13=pp.create_load(net, bus=bus56, p_mw=0.0018, q_mvar=0.00058, name="load13")
load14=pp.create_load(net, bus=bus57, p_mw=0.0018, q_mvar=0.00058, name="load14")
load15=pp.create_load(net, bus=bus58, p_mw=0.0018, q_mvar=0.00058, name="load15")
load16=pp.create_load(net, bus=bus59, p_mw=0.0018, q_mvar=0.00058, name="load16")

load17=pp.create_load(net, bus=bus62, p_mw=0.0018, q_mvar=0.00058, name="load17")
load18=pp.create_load(net, bus=bus63, p_mw=0.0018, q_mvar=0.00058, name="load18")
load19=pp.create_load(net, bus=bus64, p_mw=0.0018, q_mvar=0.00058, name="load19")
load20=pp.create_load(net, bus=bus65, p_mw=0.0018, q_mvar=0.00058, name="load20")
load21=pp.create_load(net, bus=bus66, p_mw=0.0018, q_mvar=0.00058, name="load21")
load22=pp.create_load(net, bus=bus67, p_mw=0.0018, q_mvar=0.00058, name="load22")
load23=pp.create_load(net, bus=bus68, p_mw=0.0018, q_mvar=0.00058, name="load23")
load24=pp.create_load(net, bus=bus69, p_mw=0.0018, q_mvar=0.00058, name="load24")

# %%
pp.runpp(net)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.574267  1.455885
# 1   1.007506   0.690605  0.000000  0.000000
# 2   1.020735   0.732996 -3.000000 -1.000000
# 3   1.007000   0.667045  0.000000  0.000000
# 4   1.006947   0.658862  0.000000  0.000000
# 5   1.007000   0.667045  0.000000  0.000000
# 6   0.996118  -0.265312  0.000000  0.000000
# 7   0.942500  -0.675741  0.012600  0.004100
# 8   0.894707  -1.075570  0.012600  0.004100
# 9   0.853043  -1.454220  0.012600  0.004100
# 10  0.817797  -1.799436  0.012600  0.004100
# 11  0.789236  -2.097936  0.012600  0.004100
# 12  0.767592  -2.336452  0.012600  0.004100
# 13  0.753054  -2.503103  0.012600  0.004100
# 14  0.745750  -2.588868  0.012600  0.004100
# 15  0.996064  -0.273622  0.000000  0.000000
# 16  0.942441  -0.684098  0.012600  0.004100
# 17  0.894644  -1.083981  0.012600  0.004100
# 18  0.852976  -1.462687  0.012600  0.004100
# 19  0.817726  -1.807960  0.012600  0.004100
# ...

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  \
# 0   -2.961899    -1.123514  3.000000   1.000000  0.038101 -0.123514
# 1    0.124020    -0.119213 -0.123943  -0.045986  0.000077 -0.165199
# 2    0.124044    -0.146730 -0.123947  -0.045988  0.000097 -0.192719
# 3    0.124020    -0.119213 -0.123943  -0.045986  0.000077 -0.165199
# 4    0.121981     0.043499 -0.115707  -0.040330  0.006274  0.003169
# 5    0.103107     0.036230 -0.098116  -0.033709  0.004991  0.002521
# 6    0.085516     0.029609 -0.081719  -0.027691  0.003798  0.001918
# 7    0.069119     0.023591 -0.066398  -0.022216  0.002721  0.001374
# 8    0.053798     0.018116 -0.052009  -0.017213  0.001788  0.000903
# 9    0.039409     0.013113 -0.038381  -0.012594  0.001028  0.000519
# 10   0.025781     0.008494 -0.025317  -0.008259  0.000464  0.000234
# 11   0.012717     0.004159 -0.012600  -0.004100  0.000117  0.000059
# 12   0.121985     0.043501 -0.115710  -0.040331  0.006275  0.003170
# ...

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0 -2.574267  -1.455885  2.589814   1.508670  0.015547  0.052785  0.015523
# 1  0.123943   0.045986 -0.121981  -0.043499  0.001962  0.002487  0.003790
# 2  0.123947   0.045988 -0.121985  -0.043501  0.001962  0.002487  0.003790
# 3  0.123943   0.045986 -0.121981  -0.043499  0.001962  0.002487  0.003790
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.085877  1.000000      0.000000  1.007506      0.690605        11.899496
# 1  0.187653  1.007000      0.667045  0.996118     -0.265312        32.820013
# 2  0.187669  1.006947      0.658862  0.996064     -0.273622        32.822855
# 3  0.187653  1.007000      0.667045  0.996118     -0.265312        32.820013

# %%
from pandapower.plotting.plotly import pf_res_plotly
import pandapower.plotting.plotly
pp.runpp(net)
pf_res_plotly(net)

# %% [markdown]
#    a. Are there any violations of voltage, line, or transformers?
#
#       No, There are no violations of voltage, line and tranformers.
#
#    b. Create and display a colormap of the buses showing blue for all voltages below 0.95, green for voltages between 0.95 and
#       1.05, and red for all voltages above 1.05 pu.

# %%
import pandapower.plotting as plot
pp.runpp(net)
cmap_list=[((0,0.95), "blue"),((0.95,1.05), "green"),((1.05,1.1), "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc=create_line_collection(net)
plot.draw_collections([lc,bc])

# %% [markdown]
# 4)  If we consider that each house will purchase an electric vehicle with a 7 kW charger (in addition to their normal 2 kW with
#     PF=0.95 load) and they want to charge at the same time.

# %%
#create load
load1=pp.create_load(net, bus=bus42, p_mw=0.005, q_mvar=0.00164, name="load1")
load2=pp.create_load(net, bus=bus43, p_mw=0.005, q_mvar=0.00164, name="load2")
load3=pp.create_load(net, bus=bus44, p_mw=0.005, q_mvar=0.00164, name="load3")
load4=pp.create_load(net, bus=bus45, p_mw=0.005, q_mvar=0.00164, name="load4")
load5=pp.create_load(net, bus=bus46, p_mw=0.005, q_mvar=0.00164, name="load5")
load6=pp.create_load(net, bus=bus47, p_mw=0.005, q_mvar=0.00164, name="load6")
load7=pp.create_load(net, bus=bus48, p_mw=0.005, q_mvar=0.00164, name="load7")
load8=pp.create_load(net, bus=bus49, p_mw=0.005, q_mvar=0.00164, name="load8")

load9=pp.create_load(net, bus=bus52, p_mw=0.005, q_mvar=0.00164, name="load9")
load10=pp.create_load(net, bus=bus53, p_mw=0.005, q_mvar=0.00164, name="load10")
load11=pp.create_load(net, bus=bus54, p_mw=0.005, q_mvar=0.00164, name="load11")
load12=pp.create_load(net, bus=bus55, p_mw=0.005, q_mvar=0.00164, name="load12")
load13=pp.create_load(net, bus=bus56, p_mw=0.005, q_mvar=0.00164, name="load13")
load14=pp.create_load(net, bus=bus57, p_mw=0.005, q_mvar=0.00164, name="load14")
load15=pp.create_load(net, bus=bus58, p_mw=0.005, q_mvar=0.00164, name="load15")
load16=pp.create_load(net, bus=bus59, p_mw=0.005, q_mvar=0.00164, name="load16")

load17=pp.create_load(net, bus=bus62, p_mw=0.005, q_mvar=0.00164, name="load17")
load18=pp.create_load(net, bus=bus63, p_mw=0.005, q_mvar=0.00164, name="load18")
load19=pp.create_load(net, bus=bus64, p_mw=0.005, q_mvar=0.00164, name="load19")
load20=pp.create_load(net, bus=bus65, p_mw=0.005, q_mvar=0.00164, name="load20")
load21=pp.create_load(net, bus=bus66, p_mw=0.005, q_mvar=0.00164, name="load21")
load22=pp.create_load(net, bus=bus67, p_mw=0.005, q_mvar=0.00164, name="load22")
load23=pp.create_load(net, bus=bus68, p_mw=0.005, q_mvar=0.00164, name="load23")
load24=pp.create_load(net, bus=bus69, p_mw=0.005, q_mvar=0.00164, name="load24")

# %%
pp.runpp(net)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.293884  1.328123
# 1   1.006832   0.615710  0.000000  0.000000
# 2   1.020070   0.658178 -3.000000 -1.000000
# 3   1.005801   0.593618  0.000000  0.000000
# 4   1.005659   0.585692  0.000000  0.000000
# 5   1.005801   0.593618  0.000000  0.000000
# 6   0.985371  -1.044193  0.000000  0.000000
# 7   0.889030  -1.656072  0.017600  0.005740
# 8   0.801356  -2.314409  0.017600  0.005740
# 9   0.723290  -3.008004  0.017600  0.005740
# 10  0.655852  -3.714232  0.017600  0.005740
# 11  0.600114  -4.395178  0.017600  0.005740
# 12  0.557132  -4.996379  0.017600  0.005740
# 13  0.527857  -5.452040  0.017600  0.005740
# 14  0.513020  -5.699458  0.017600  0.005740
# 15  0.985211  -1.053637  0.000000  0.000000
# 16  0.888788  -1.665782  0.017600  0.005740
# 17  0.801036  -2.324562  0.017600  0.005740
# 18  0.722895  -3.018815  0.017600  0.005740
# 19  0.655388  -3.725929  0.017600  0.005740
# ...

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  \
# 0   -2.961850    -1.123309  3.000000   1.000000  0.038150 -0.123309
# 1    0.217511    -0.073983 -0.217292  -0.090848  0.000219 -0.164832
# 2    0.217689    -0.101345 -0.217433  -0.090931  0.000256 -0.192276
# 3    0.217511    -0.073983 -0.217292  -0.090848  0.000219 -0.164832
# 4    0.214011     0.082901 -0.193874  -0.072730  0.020136  0.010172
# 5    0.176274     0.066990 -0.159574  -0.058554  0.016700  0.008436
# 6    0.141974     0.052814 -0.128711  -0.046114  0.013263  0.006700
# 7    0.111111     0.040374 -0.101195  -0.035365  0.009916  0.005009
# 8    0.083595     0.029625 -0.076807  -0.026196  0.006788  0.003429
# 9    0.059207     0.020456 -0.055163  -0.018413  0.004044  0.002043
# 10   0.037563     0.012673 -0.035683  -0.011724  0.001879  0.000949
# 11   0.018083     0.005984 -0.017600  -0.005740  0.000483  0.000244
# 12   0.214149     0.082971 -0.193979  -0.072782  0.020170  0.010189
# ...

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0 -2.293884  -1.328123  2.309139   1.372622  0.015255  0.044498  0.013912
# 1  0.217292   0.090848 -0.214011  -0.082901  0.003281  0.007947  0.006760
# 2  0.217433   0.090931 -0.214149  -0.082971  0.003284  0.007960  0.006765
# 3  0.217292   0.090848 -0.214011  -0.082901  0.003281  0.007947  0.006760
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.077021  1.000000      0.000000  1.006832      0.615710        10.672292
# 1  0.336182  1.005801      0.593618  0.985371     -1.044193        58.540056
# 2  0.336463  1.005659      0.585692  0.985211     -1.053637        58.588632
# 3  0.336182  1.005801      0.593618  0.985371     -1.044193        58.540056

# %%
from pandapower.plotting.plotly import pf_res_plotly
import pandapower.plotting.plotly
pp.runpp(net)
pf_res_plotly(net)

# %% [markdown]
#
#     a. Is the system able to withstand this load?
#        Yes, The system is able to withstand this load.
#
#
#     b. If no, propose some solutions to alleviate the problem.
#        If the system is unable to withstand the load it might be due to rise in loading of transformers, lines or buses. In
#        this case we have to change them by looking into the manufacturer details and as per the required ratings. In case of
#        loading in transformers we can use another transformer in parallel for load sharing.

# %% [markdown]
# ##  3.Short circuit analysis
#
# ### 3.1 Tasks
#
# 1. Compute the maximum three-phase short-circuit currents for a solid fault (ZF=0 Ω).
#
#    a. Present the initial symmetrical short-circuit current, the short-circuit current
#       peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, ip=True, ith=True, branch_results=True)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka     skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.544779  100.000000   1.039833  0.547460  43.969642  125.627547
# 1   2.154304   70.832867   4.435416  2.168940   1.517492    6.023599
# 2   1.835268   59.781143   3.243817  1.842178   3.082492    6.683599
# 3   1.757434   57.783918   3.051211  1.763578   3.395492    6.815599
# 4   1.699228   55.870123   2.899378  1.704790   3.708492    6.947599
# 5   1.757434   57.783918   3.051211  1.763578   3.395492    6.815599
# 6   9.835564    6.467809  19.915061  9.897797   0.007113    0.026265
# 7   3.072391    2.020386   4.544073  3.077455   0.066503    0.056265
# 8   1.753726    1.153240   2.556174  1.756279   0.125893    0.086265
# 9   1.223558    0.804605   1.776722  1.225272   0.185283    0.116265
# 10  0.938901    0.617416   1.361183  0.940193   0.244673    0.146265
# ...

# %% [markdown]
#    b. Present the initial symmetrical short-circuit current, the short-circuit current peak, and the equivalent thermal short-        circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.725733  3.088911  1.732230
# 1   1.757434  3.051211  1.763578
# 2   1.699228  2.899378  1.704790
# 3   1.757434  3.051211  1.763578
# 4   3.072391  4.544073  3.077455
# 5   1.753726  2.556174  1.756279
# 6   1.223558  1.776722  1.225272
# 7   0.938901  1.361183  0.940193
# 8   0.761516  1.103055  0.762553
# 9   0.640440  0.927175  0.641307
# 10  0.552553  0.799648  0.553298
# 11  0.485863  0.702950  0.486516
# 12  3.067824  4.536929  3.072877
# 13  1.752197  2.553898  1.754747
# 14  1.222808  1.775619  1.224521
# 15  0.938458  1.360534  0.939749
# 16  0.761224  1.102629  0.762261
# 17  0.640233  0.926874  0.641100
# 18  0.552399  0.799424  0.553144
# 19  0.485744  0.702776  0.486397
# 20  3.072391  4.544073  3.077455
# 21  1.753726  2.556174  1.756279
# 22  1.223558  1.776722  1.225272
# 23  0.938901  1.361183  0.940193
# 24  0.761516  1.103055  0.762553
# 25  0.640440  0.927175  0.641307
# 26  0.552553  0.799648  0.553298
# ...

# %%
net.res_trafo_sc
# Out:
#    ikss_hv_ka  ikss_lv_ka
# 0    0.371776    2.044769
# 1    0.196711    9.835564
# 2    0.196107    9.805331
# 3    0.196711    9.835564

# %% [markdown]
# c. What is the difference between the three values of current computed at each
#    node or line?
#
#     The peak short circuit current is high but the difference between initial symmetrical short circuit current and the
#     equivalent thermal short circuit current is very slight.
#
#
# d. Which standard is used to compute the short-circuit currents? Briefly explain
#    the methodology based on the documentation, the slides of the course, and
#    material you find online.
#
#    DIN/IEC EN 60909 is the standard used to compute the short-circuit currents.
#
#    The following below are the methods used to find the short-circuit currents:
#    1) Superposition method for a defined load flow case.
#       The superposition method is an exact method for the calculation of the shortcircuit currents. The method consists of
#       three steps. The voltage ratios and the loading condition of the network must be known before the occurrence of the short       circuit. In the first step, the currents, voltages, and internal voltages for steady-state operation before onset of the       short circuit are calculated. The calculation considers the impedances, power supply feeders, and node loads of the             active elements. In the second step, the voltage applied to the fault location before the occurrence of the short circuit       and the current distribution at the fault location are determined with a negative sign. This is the only voltage source         in the network. The internal voltages are shortcircuited. In the third step, both the conditions are superimposed. We           then obtain a zero voltage at the fault location. The superposition of the currents also leads to the value zero. The           disadvantage of this method is that the steady-state condition must be specified.
#
#    2) Calculating with the equivalent voltage source at the fault location.
#       This method assumes the following conditions:
#       1) The passive loads and conductor capacitances can be neglected
#       2) The step setting of the transformers need not be considered
#       3) The excitation of the generators need not be considered
#       4) The time and position dependence of the previous load (loading state) of the network need not be considered.
#
#   3) Transient calculation.
#       With the transient method, the individual operating equipment and, as a result, the entire network are represented by a         system of differential equations. The calculation is very tedious. The method with the equivalent voltage source is a
#       simplification relative to the other methods. Since 1988, it has been standardized internationally in IEC 60909-0. The         calculation is independent of a current operational state.

# %% [markdown]
#   2) Deactivate the contribution of the large motor4 and re-compute the maximum threephase short-circuit currents for a solid      fault (ZF=0 ohms)

# %%
net.sgen.in_service=False

# %% [markdown]
# a. Present the initial symmetrical short-circuit current, the short-circuit current
#    peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, ip=True, ith=True, branch_results=True)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka     skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.524864  100.000000   1.011668  0.527447  43.969642  125.627547
# 1   2.044769   70.832867   4.280510  2.058661   1.517492    6.023599
# 2   1.725733   59.781143   3.088911  1.732230   3.082492    6.683599
# 3   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 4   1.612832   55.870123   2.777194  1.618110   3.708492    6.947599
# 5   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 6   9.335478    6.467809  19.207832  9.394547   0.007113    0.026265
# 7   2.916176    2.020386   4.323152  2.920983   0.066503    0.056265
# 8   1.664558    1.153240   2.430072  1.666981   0.125893    0.086265
# 9   1.161347    0.804605   1.688742  1.162973   0.185283    0.116265
# 10  0.891163    0.617416   1.293671  0.892389   0.244673    0.146265
# ...

# %% [markdown]
#  b. Present the initial symmetrical short-circuit current, the short-circuit current peak, and the equivalent thermal short-
#     circuit current at each line

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.725733  3.088911  1.732230
# 1   1.668078  2.924842  1.673910
# 2   1.612832  2.777194  1.618110
# 3   1.668078  2.924842  1.673910
# 4   2.916176  4.323152  2.920983
# 5   1.664558  2.430072  1.666981
# 6   1.161347  1.688742  1.162973
# 7   0.891163  1.293671  0.892389
# 8   0.722797  1.048298  0.723782
# 9   0.607877  0.881124  0.608700
# 10  0.524459  0.759917  0.525166
# 11  0.461159  0.668014  0.461779
# 12  2.911841  4.316336  2.916637
# 13  1.663108  2.427905  1.665528
# 14  1.160635  1.687693  1.162260
# 15  0.890743  1.293054  0.891968
# 16  0.722520  1.047893  0.723504
# 17  0.607680  0.880838  0.608503
# 18  0.524313  0.759704  0.525019
# 19  0.461046  0.667849  0.461666
# 20  2.916176  4.323152  2.920983
# 21  1.664558  2.430072  1.666981
# 22  1.161347  1.688742  1.162973
# 23  0.891163  1.293671  0.892389
# 24  0.722797  1.048298  0.723782
# 25  0.607877  0.881124  0.608700
# 26  0.524459  0.759917  0.525166
# ...

# %%
net.res_trafo_sc
# Out:
#    ikss_hv_ka  ikss_lv_ka
# 0    0.371776    2.044769
# 1    0.186710    9.335478
# 2    0.186136    9.306782
# 3    0.186710    9.335478

# %% [markdown]
# c. Compare to the values of Task 1 and explain the difference.
#
#     When compared to the values of task 1, There is a slight difference between the currents which is negligible.

# %%
net.sgen.in_service=True

# %% [markdown]
# 3) Compute the maximum three-phase short-circuit currents with fault impedance ZF=1+j1.5 Ω.
#
# a. Present the initial symmetrical short-circuit current, the short-circuit current
#    peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, ip=True, ith=True, branch_results=True, r_fault_ohm=1, x_fault_ohm=1.5)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka    skss_mw     ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.537980  98.704543  1.028554  0.540645  44.969642  127.127547
# 1   1.710533  55.460188  3.488893  1.721903   2.517492    7.523599
# 2   1.498400  48.111706  2.753461  1.505015   4.082492    8.183599
# 3   1.439765  46.779523  2.611587  1.445753   4.395492    8.315599
# 4   1.399752  45.495973  2.502729  1.405265   4.708492    8.447599
# 5   1.439765  46.779523  2.611587  1.445753   4.395492    8.315599
# 6   0.639009   0.096249  0.994130  0.643114   1.007113    1.526265
# 7   0.290864   0.093288  0.495668  0.292644   1.066503    1.556265
# 8   0.219762   0.090478  0.389523  0.221047   1.125893    1.586265
# 9   0.188956   0.087811  0.340833  0.190015   1.185283    1.616265
# 10  0.170827   0.085278  0.310493  0.171746   1.244673    1.646265
# 11  0.158333   0.082871  0.288505  0.159153   1.304063    1.676265
# ...

# %% [markdown]
# b. Present the initial symmetrical short-circuit current, the short-circuit current
#    peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.388865  2.598556  1.394997
# 1   1.439765  2.611587  1.445753
# 2   1.399752  2.502729  1.405265
# 3   1.439765  2.611587  1.445753
# 4   0.290864  0.495668  0.292644
# 5   0.219762  0.389523  0.221047
# 6   0.188956  0.340833  0.190015
# 7   0.170827  0.310493  0.171746
# 8   0.158333  0.288505  0.159153
# 9   0.148873  0.271153  0.149617
# 10  0.141260  0.256727  0.141942
# 11  0.134875  0.244322  0.135506
# 12  0.290624  0.495316  0.292402
# 13  0.219676  0.389391  0.220961
# 14  0.188911  0.340758  0.189969
# 15  0.170797  0.310442  0.171716
# 16  0.158312  0.288466  0.159132
# 17  0.148856  0.271121  0.149600
# 18  0.141246  0.256700  0.141928
# 19  0.134864  0.244298  0.135494
# 20  0.290864  0.495668  0.292644
# 21  0.219762  0.389523  0.221047
# 22  0.188956  0.340833  0.190015
# 23  0.170827  0.310493  0.171746
# 24  0.158333  0.288505  0.159153
# 25  0.148873  0.271153  0.149617
# 26  0.141260  0.256727  0.141942
# ...

# %%
net.res_trafo_sc
# Out:
#    ikss_hv_ka  ikss_lv_ka
# 0    0.291090    1.600998
# 1    0.012780    0.639009
# 2    0.012749    0.637463
# 3    0.012780    0.639009

# %% [markdown]
# c. Compare to the values of Task 1 and explain the difference.
#
#     When compared the values to Task 1, There is a decrease in value of all three currents because of fault impedance.
#
# 4) Compute the maximum two-phase short-circuit currents for a solid fault (ZF=0 Ω).
#
# a. Present the initial symmetrical short-circuit current, the short-circuit current
#    peak, and the equivalent thermal short-circuit current at each bus.

# %%
import pandapower.shortcircuit as sc

sc.calc_sc(net, fault="2ph", ip=True, ith=True, branch_results=True)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka    skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.474461  28.867513   0.904295  0.476796  43.969642  125.627547
# 1   1.880357  20.447687   3.861936  1.893132   1.517492    6.023599
# 2   1.604063  17.257330   2.829981  1.610103   3.082492    6.683599
# 3   1.533954  16.680780   2.659356  1.539317   3.395492    6.815599
# 4   1.483150  16.128315   2.527304  1.488004   3.708492    6.947599
# 5   1.533954  16.680780   2.659356  1.539317   3.395492    6.815599
# 6   8.584847   1.867096  17.341699  8.639166   0.007113    0.026265
# 7   2.681698   0.583235   3.964880  2.686118   0.066503    0.056265
# 8   1.530717   0.332912   2.230606  1.532945   0.125893    0.086265
# 9   1.067967   0.232269   1.550474  1.069463   0.185283    0.116265
# 10  0.819508   0.178233   1.187864  0.820636   0.244673    0.146265
# ...

# %% [markdown]
# b. Present the initial symmetrical short-circuit current, the short-circuit current
#    peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.494529  2.675075  1.500155
# 1   1.533954  2.659356  1.539317
# 2   1.483150  2.527304  1.488004
# 3   1.533954  2.659356  1.539317
# 4   2.681698  3.964880  2.686118
# 5   1.530717  2.230606  1.532945
# 6   1.067967  1.550474  1.069463
# 7   0.819508  1.187864  0.820636
# 8   0.664679  0.962610  0.665585
# 9   0.559000  0.809127  0.559756
# 10  0.482289  0.697839  0.482939
# 11  0.424079  0.613453  0.424649
# 12  2.677711  3.958650  2.682122
# 13  1.529383  2.228620  1.531609
# 14  1.067313  1.549511  1.068807
# 15  0.819121  1.187298  0.820248
# 16  0.664425  0.962238  0.665330
# 17  0.558819  0.808864  0.559576
# 18  0.482155  0.697643  0.482805
# 19  0.423975  0.613302  0.424545
# 20  2.681698  3.964880  2.686118
# 21  1.530717  2.230606  1.532945
# 22  1.067967  1.550474  1.069463
# 23  0.819508  1.187864  0.820636
# 24  0.664679  0.962610  0.665585
# 25  0.559000  0.809127  0.559756
# 26  0.482289  0.697839  0.482939
# ...

# %%
net.res_trafo_sc
# Out:
#    ikss_hv_ka  ikss_lv_ka
# 0    0.321968    1.770822
# 1    0.171697    8.584847
# 2    0.171169    8.558458
# 3    0.171697    8.584847

# %% [markdown]
# c. Compare to the values of Task 1 and explain the difference.
#
#     When compared to the values of Task 1, The value of all three currents decreased because of two phase short circuit.
