# %%
import pandapower as pp

import pandapower.shortcircuit as sc

import pandapower.plotting as plot

net=pp.create_empty_network(name="system")


#create buses
b1=pp.create_bus(net,vn_kv=110, name="bus 1")
b2=pp.create_bus(net,vn_kv=20, name="bus 2")
b3=pp.create_bus(net,vn_kv=20, name="bus 3")
b4=pp.create_bus(net,vn_kv=20, name="bus 4")
b5=pp.create_bus(net,vn_kv=20, name="bus 5")
b6=pp.create_bus(net,vn_kv=20, name="bus 6")
b41=pp.create_bus(net,vn_kv=0.4, name="bus 41")
b42=pp.create_bus(net,vn_kv=0.4, name="bus 42")
b43=pp.create_bus(net,vn_kv=0.4, name="bus 43")
b44=pp.create_bus(net,vn_kv=0.4, name="bus 44")
b45=pp.create_bus(net,vn_kv=0.4, name="bus 45")
b46=pp.create_bus(net,vn_kv=0.4, name="bus 46")
b47=pp.create_bus(net,vn_kv=0.4, name="bus 47")
b48=pp.create_bus(net,vn_kv=0.4, name="bus 48")
b49=pp.create_bus(net,vn_kv=0.4, name="bus 49")
b51=pp.create_bus(net,vn_kv=0.4, name="bus 51")
b52=pp.create_bus(net,vn_kv=0.4, name="bus 52")
b53=pp.create_bus(net,vn_kv=0.4, name="bus 53")
b54=pp.create_bus(net,vn_kv=0.4, name="bus 54")
b55=pp.create_bus(net,vn_kv=0.4, name="bus 55")
b56=pp.create_bus(net,vn_kv=0.4, name="bus 56")
b57=pp.create_bus(net,vn_kv=0.4, name="bus 57")
b58=pp.create_bus(net,vn_kv=0.4, name="bus 58")
b59=pp.create_bus(net,vn_kv=0.4, name="bus 59")
b61=pp.create_bus(net,vn_kv=0.4, name="bus 61")
b62=pp.create_bus(net,vn_kv=0.4, name="bus 62")
b63=pp.create_bus(net,vn_kv=0.4, name="bus 63")
b64=pp.create_bus(net,vn_kv=0.4, name="bus 64")
b65=pp.create_bus(net,vn_kv=0.4, name="bus 65")
b66=pp.create_bus(net,vn_kv=0.4, name="bus 66")
b67=pp.create_bus(net,vn_kv=0.4, name="bus 67")
b68=pp.create_bus(net,vn_kv=0.4, name="bus 68")
b69=pp.create_bus(net,vn_kv=0.4, name="bus 69")

#External Bus
pp.create_ext_grid(net,b1,s_sc_max_mva=100,s_sc_min_mva=80, rx_max=0.35,rx_min=0.20,name="External grid")





#Create Transformer...net, hv_bus to lv_bus, standard type

pp.create_transformer(net,b1,b2,std_type="25 MVA 110/20 kV")
pp.create_transformer(net,b4,b41,std_type="0.4 MVA 20/0.4 kV")
pp.create_transformer(net,b5,b51,std_type="0.4 MVA 20/0.4 kV")
pp.create_transformer(net,b6,b61,std_type="0.4 MVA 20/0.4 kV")

#create lines....net, from_bus to to_bus, standard type, length , name

pp.create_line(net,b2,b3,std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=5, name="line 1")
pp.create_line(net,b2,b4,std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=6, name="line 2")
pp.create_line(net,b2,b5,std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=7, name="line 3")
pp.create_line(net,b2,b6,std_type="NA2XS2Y 1x95 RM/25 12/20 kV", length_km=6, name="line 4")

# Create LV lines

pp.create_line(net,b41,b42,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 5")
pp.create_line(net,b42,b43,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 6")
pp.create_line(net,b43,b44,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 7")
pp.create_line(net,b44,b45,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 8")
pp.create_line(net,b45,b46,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 9")
pp.create_line(net,b46,b47,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 10")
pp.create_line(net,b47,b48,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 11")
pp.create_line(net,b48,b49,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 12")
pp.create_line(net,b51,b52,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 13")
pp.create_line(net,b52,b53,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 14")
pp.create_line(net,b53,b54,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 15")
pp.create_line(net,b54,b55,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 16")
pp.create_line(net,b55,b56,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 17")
pp.create_line(net,b56,b57,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 18")
pp.create_line(net,b57,b58,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 19")
pp.create_line(net,b58,b59,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 20")
pp.create_line(net,b61,b62,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 21")
pp.create_line(net,b62,b63,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 22")
pp.create_line(net,b63,b64,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 23")
pp.create_line(net,b64,b65,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 24")
pp.create_line(net,b65,b67,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 25")
pp.create_line(net,b67,b68,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 26")
pp.create_line(net,b68,b69,std_type="48-AL1/8-ST1A 0.4", length_km=0.1, name="line 27")



#create load

pp.create_load(net,b3,p_mw=3,q_mvar=1)


#create LV Load

pp.create_load(net,b41,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b42,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b43,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b44,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b45,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b46,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b47,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b48,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b49,p_mw=0.0022,q_mvar=0.00241)

pp.create_load(net,b51,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b52,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b53,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b54,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b55,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b56,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b57,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b58,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b59,p_mw=0.0022,q_mvar=0.00241)

pp.create_load(net,b61,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b62,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b63,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b64,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b65,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b66,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b67,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b68,p_mw=0.0022,q_mvar=0.00241)
pp.create_load(net,b69,p_mw=0.0022,q_mvar=0.00241)


pp.runpp(net)
net
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (33 elements)
#    - load (28 elements)
#    - ext_grid (1 element)
#    - line (27 elements)
#    - trafo (4 elements)
#  and the following results tables:
#    - res_bus (33 elements)
#    - res_line (27 elements)
#    - res_trafo (4 elements)
#    - res_ext_grid (1 element)
#    - res_load (28 elements)

# %% [markdown]
# # Run Power Flow

# %% [markdown]
# We can now use pandas functionality to analyse the loadflow results, for example to get the minimum voltage in the medium voltage level:

# %%
net.res_bus[net.bus.vn_kv==20].vm_pu.min()
# Out:
# 0.9837608129814084

# %%
net.res_bus[net.bus.vn_kv==0.4].vm_pu.min()
# Out:
# 0.9452231792439808

# %%
snet.load
# Out:
#     name  bus    p_mw   q_mvar  const_z_percent  const_i_percent  sn_mva  \
# 0   None    2  3.0000  1.00000              0.0              0.0     NaN
# 1   None    6  0.0022  0.00241              0.0              0.0     NaN
# 2   None    7  0.0022  0.00241              0.0              0.0     NaN
# 3   None    8  0.0022  0.00241              0.0              0.0     NaN
# 4   None    9  0.0022  0.00241              0.0              0.0     NaN
# 5   None   10  0.0022  0.00241              0.0              0.0     NaN
# 6   None   11  0.0022  0.00241              0.0              0.0     NaN
# 7   None   12  0.0022  0.00241              0.0              0.0     NaN
# 8   None   13  0.0022  0.00241              0.0              0.0     NaN
# 9   None   14  0.0022  0.00241              0.0              0.0     NaN
# 10  None   15  0.0022  0.00241              0.0              0.0     NaN
# 11  None   16  0.0022  0.00241              0.0              0.0     NaN
# ...

# %%
net.res_load
# Out:
#       p_mw   q_mvar
# 0   3.0000  1.00000
# 1   0.0022  0.00241
# 2   0.0022  0.00241
# 3   0.0022  0.00241
# 4   0.0022  0.00241
# 5   0.0022  0.00241
# 6   0.0022  0.00241
# 7   0.0022  0.00241
# 8   0.0022  0.00241
# 9   0.0022  0.00241
# 10  0.0022  0.00241
# 11  0.0022  0.00241
# 12  0.0022  0.00241
# 13  0.0022  0.00241
# 14  0.0022  0.00241
# 15  0.0022  0.00241
# 16  0.0022  0.00241
# 17  0.0022  0.00241
# 18  0.0022  0.00241
# 19  0.0022  0.00241
# 20  0.0022  0.00241
# 21  0.0022  0.00241
# 22  0.0022  0.00241
# 23  0.0022  0.00241
# 24  0.0000  0.00000
# 25  0.0022  0.00241
# 26  0.0022  0.00241
# 27  0.0022  0.00241

# %%
pp.runpp(net)
net.res_bus.va_degree
# Out:
# 0     0.000000
# 1    -0.853228
# 2    -0.928826
# 3    -0.871624
# 4    -0.878950
# 5    -0.872039
# 6    -1.005970
# 7    -0.779585
# 8    -0.577440
# 9    -0.401063
# 10   -0.251830
# 11   -0.130936
# 12   -0.039370
# 13    0.022107
# 14    0.052977
# 15   -1.013287
# 16   -0.786918
# 17   -0.584787
# 18   -0.408423
# 19   -0.259200
# 20   -0.138315
# 21   -0.046755
# 22    0.014717
# 23    0.045584
# 24   -0.990615
# 25   -0.793008
# 26   -0.620661
# 27   -0.474889
# 28   -0.356834
# 29         NaN
# 30   -0.267439
# 31   -0.207430
# 32   -0.177301
# Name: va_degree, dtype: float64

# %%
net.bus
# Out:
#       name  vn_kv type  zone  in_service
# 0    bus 1  110.0    b  None        True
# 1    bus 2   20.0    b  None        True
# 2    bus 3   20.0    b  None        True
# 3    bus 4   20.0    b  None        True
# 4    bus 5   20.0    b  None        True
# 5    bus 6   20.0    b  None        True
# 6   bus 41    0.4    b  None        True
# 7   bus 42    0.4    b  None        True
# 8   bus 43    0.4    b  None        True
# 9   bus 44    0.4    b  None        True
# 10  bus 45    0.4    b  None        True
# 11  bus 46    0.4    b  None        True
# 12  bus 47    0.4    b  None        True
# 13  bus 48    0.4    b  None        True
# 14  bus 49    0.4    b  None        True
# 15  bus 51    0.4    b  None        True
# 16  bus 52    0.4    b  None        True
# 17  bus 53    0.4    b  None        True
# 18  bus 54    0.4    b  None        True
# 19  bus 55    0.4    b  None        True
# 20  bus 56    0.4    b  None        True
# 21  bus 57    0.4    b  None        True
# ...

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000 -3.119244 -0.493107
# 1   0.997260  -0.853228  0.000000  0.000000
# 2   0.983761  -0.928826  3.000000  1.000000
# 3   0.997273  -0.871624  0.000000  0.000000
# 4   0.997306  -0.878950  0.000000  0.000000
# 5   0.997290  -0.872039  0.000000  0.000000
# 6   0.993257  -1.005970  0.002200  0.002410
# 7   0.982633  -0.779585  0.002200  0.002410
# 8   0.973313  -0.577440  0.002200  0.002410
# 9   0.965308  -0.401063  0.002200  0.002410
# 10  0.958624  -0.251830  0.002200  0.002410
# 11  0.953269  -0.130936  0.002200  0.002410
# 12  0.949248  -0.039370  0.002200  0.002410
# 13  0.946565   0.022107  0.002200  0.002410
# 14  0.945223   0.052977  0.002200  0.002410
# 15  0.993290  -1.013287  0.002200  0.002410
# 16  0.982667  -0.786918  0.002200  0.002410
# 17  0.973347  -0.584787  0.002200  0.002410
# 18  0.965342  -0.408423  0.002200  0.002410
# 19  0.958659  -0.259200  0.002200  0.002410
# ...

# %%
net.line
# Out:
#        name                     std_type  from_bus  to_bus  length_km  \
# 0    line 1  NA2XS2Y 1x95 RM/25 12/20 kV         1       2        5.0
# 1    line 2  NA2XS2Y 1x95 RM/25 12/20 kV         1       3        6.0
# 2    line 3  NA2XS2Y 1x95 RM/25 12/20 kV         1       4        7.0
# 3    line 4  NA2XS2Y 1x95 RM/25 12/20 kV         1       5        6.0
# 4    line 5            48-AL1/8-ST1A 0.4         6       7        0.1
# 5    line 6            48-AL1/8-ST1A 0.4         7       8        0.1
# 6    line 7            48-AL1/8-ST1A 0.4         8       9        0.1
# 7    line 8            48-AL1/8-ST1A 0.4         9      10        0.1
# 8    line 9            48-AL1/8-ST1A 0.4        10      11        0.1
# 9   line 10            48-AL1/8-ST1A 0.4        11      12        0.1
# 10  line 11            48-AL1/8-ST1A 0.4        12      13        0.1
# 11  line 12            48-AL1/8-ST1A 0.4        13      14        0.1
# ...

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  \
# 0    3.039914     0.883673 -3.000000  -1.000000  0.039914 -0.116327
# 1    0.022075    -0.139687 -0.022056  -0.022276  0.000019 -0.161963
# 2    0.022088    -0.166683 -0.022056  -0.022276  0.000031 -0.188959
# 3    0.019580    -0.142276 -0.019560  -0.019690  0.000020 -0.161965
# 4    0.018485     0.019727 -0.018210  -0.019588  0.000275  0.000139
# 5    0.016010     0.017178 -0.015798  -0.017071  0.000212  0.000107
# 6    0.013598     0.014661 -0.013441  -0.014582  0.000157  0.000079
# 7    0.011241     0.012172 -0.011132  -0.012116  0.000109  0.000055
# 8    0.008932     0.009706 -0.008862  -0.009671  0.000070  0.000035
# 9    0.006662     0.007261 -0.006622  -0.007241  0.000040  0.000020
# 10   0.004422     0.004831 -0.004404  -0.004822  0.000018  0.000009
# 11   0.002204     0.002412 -0.002200  -0.002410  0.000004  0.000002
# 12   0.018485     0.019727 -0.018210  -0.019588  0.000275  0.000139
# ...

# %%
net.trafo
# Out:
#    name           std_type  hv_bus  lv_bus  sn_mva  vn_hv_kv  vn_lv_kv  \
# 0  None   25 MVA 110/20 kV       0       1    25.0     110.0      20.0
# 1  None  0.4 MVA 20/0.4 kV       3       6     0.4      20.0       0.4
# 2  None  0.4 MVA 20/0.4 kV       4      15     0.4      20.0       0.4
# 3  None  0.4 MVA 20/0.4 kV       5      24     0.4      20.0       0.4
#
#    vk_percent  vkr_percent  pfe_kw  ...  tap_neutral  tap_min tap_max  \
# 0        12.0        0.410   14.00  ...            0       -9       9
# 1         6.0        1.425    1.35  ...            0       -2       2
# 2         6.0        1.425    1.35  ...            0       -2       2
# 3         6.0        1.425    1.35  ...            0       -2       2
#
#    tap_step_percent  tap_step_degree  tap_pos  tap_phase_shifter  parallel  \
# 0               1.5              0.0        0              False         1
# 1               2.5              0.0        0              False         1
# ...

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0  3.119244   0.493107 -3.103656  -0.435028  0.015588  0.058080  0.016575
# 1  0.022056   0.022276 -0.020685  -0.022137  0.001371  0.000140  0.000907
# 2  0.022056   0.022276 -0.020685  -0.022137  0.001371  0.000140  0.000907
# 3  0.019560   0.019690 -0.018196  -0.019580  0.001365  0.000109  0.000803
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.090719  1.000000      0.000000  0.997260     -0.853228        12.631922
# 1  0.044027  0.997273     -0.871624  0.993257     -1.005970         7.858526
# 2  0.044025  0.997306     -0.878950  0.993290     -1.013287         7.858260
# 3  0.038824  0.997290     -0.872039  0.993740     -0.990615         6.957336

# %%
net.res_ext_grid
# Out:
#        p_mw    q_mvar
# 0  3.119244  0.493107

# %% [markdown]
# 2 a) Yes, there is slight variation in the voltage, line, or transformers. With respective to 5% deviation, there is no violation of voltage.

# %% [markdown]
# 2 b) Creating and displaying a colormap of the buses showing blue for all voltages below
# 0.95, green for voltages between 0.95 and 1.05, and red for all voltages above
# 1.05 pu.

# %% [markdown]
# 3) Considering that the power consumption of every household is increased to 4 kW at 0.95
# power factor and solve the power flow.

# %%
pp.create_load(net,b41,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b42,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b43,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b44,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b45,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b46,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b47,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b48,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b49,p_mw=0.004,q_mvar=0.00421)

pp.create_load(net,b51,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b52,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b53,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b54,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b55,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b56,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b57,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b58,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b59,p_mw=0.004,q_mvar=0.00421)

pp.create_load(net,b61,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b62,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b63,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b64,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b65,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b66,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b67,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b68,p_mw=0.004,q_mvar=0.00421)
pp.create_load(net,b69,p_mw=0.004,q_mvar=0.00421)
# Out:
# 54

# %%
pp.runpp(net)
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000 -3.243824 -0.620985
# 1   0.996635  -0.886920  0.000000  0.000000
# 2   0.983127  -0.962594  3.000000  1.000000
# 3   0.996356  -0.898714  0.000000  0.000000
# 4   0.996341  -0.904937  0.000000  0.000000
# 5   0.996417  -0.899946  0.000000  0.000000
# 6   0.984542  -1.317590  0.006200  0.006620
# 7   0.951859  -0.684306  0.006200  0.006620
# 8   0.923007  -0.093242  0.006200  0.006620
# 9   0.898083   0.443719  0.006200  0.006620
# 10  0.877174   0.914566  0.006200  0.006620
# 11  0.860354   1.307761  0.006200  0.006620
# 12  0.847685   1.612915  0.006200  0.006620
# 13  0.839212   1.821476  0.006200  0.006620
# 14  0.834968   1.927345  0.006200  0.006620
# 15  0.984527  -1.323829  0.006200  0.006620
# 16  0.951843  -0.690524  0.006200  0.006620
# 17  0.922990  -0.099439  0.006200  0.006620
# 18  0.898066   0.437542  0.006200  0.006620
# 19  0.877157   0.908408  0.006200  0.006620
# ...

# %% [markdown]
# 3 a) There is no violation of voltage, line or transformer.

# %% [markdown]
# 4 ) considering that each house will purchase an electric vehicle with a 7 kW charger (in
# addition to their normal 2 kW with PF=0.95 load) and they want to charge at the same
# time

# %%
pp.create_load(net,b41,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b42,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b43,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b44,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b45,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b46,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b47,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b48,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b49,p_mw=0.009,q_mvar=0.00921)

pp.create_load(net,b51,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b52,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b53,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b54,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b55,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b56,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b57,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b58,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b59,p_mw=0.009,q_mvar=0.00921)

pp.create_load(net,b61,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b62,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b63,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b64,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b65,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b66,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b67,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b68,p_mw=0.009,q_mvar=0.00921)
pp.create_load(net,b69,p_mw=0.009,q_mvar=0.00921)
# Out:
# 81

# %%
net.load
# Out:
#     name  bus    p_mw   q_mvar  const_z_percent  const_i_percent  sn_mva  \
# 0   None    2  3.0000  1.00000              0.0              0.0     NaN
# 1   None    6  0.0022  0.00241              0.0              0.0     NaN
# 2   None    7  0.0022  0.00241              0.0              0.0     NaN
# 3   None    8  0.0022  0.00241              0.0              0.0     NaN
# 4   None    9  0.0022  0.00241              0.0              0.0     NaN
# ..   ...  ...     ...      ...              ...              ...     ...
# 77  None   28  0.0090  0.00921              0.0              0.0     NaN
# 78  None   29  0.0090  0.00921              0.0              0.0     NaN
# 79  None   30  0.0090  0.00921              0.0              0.0     NaN
# 80  None   31  0.0090  0.00921              0.0              0.0     NaN
# 81  None   32  0.0090  0.00921              0.0              0.0     NaN
#
#     scaling  in_service type
# 0       1.0        True  wye
# 1       1.0        True  wye
# ...

# %% [markdown]
# 4 a) No, the system is not able to withstand the given load.

# %% [markdown]
# 4 b) Inorder to get avoid this problem, place some transformers between the load.

# %% [markdown]
# ## Short circuit Analysis

# %% [markdown]
# 1 ) Computing the maximum three-phase short-circuit currents for a solid fault (ZF=0 Ω).

# %% [markdown]
# 1 a ) The initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each bus.

# %%
pp.shortcircuit.calc_sc(net, case='max', ip=True, ith=True, branch_results=True)
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers

# %%
net.res_bus_sc
# Out:
#      ikss_ka     skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.524864  100.000000   1.011668  0.527447  43.969642  125.627547
# 1   2.044769   70.832867   4.280510  2.058661   1.517492    6.023599
# 2   1.725733   59.781143   3.088911  1.732230   3.082492    6.683599
# 3   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 4   1.612832   55.870123   2.777194  1.618110   3.708492    6.947599
# 5   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 6   9.335478    6.467809  19.207832  9.394547   0.007113    0.026265
# 7   2.916176    2.020386   4.323152  2.920983   0.066503    0.056265
# 8   1.664558    1.153240   2.430072  1.666981   0.125893    0.086265
# 9   1.161347    0.804605   1.688742  1.162973   0.185283    0.116265
# 10  0.891163    0.617416   1.293671  0.892389   0.244673    0.146265
# 11  0.722797    0.500768   1.048298  0.723782   0.304063    0.176265
# 12  0.607877    0.421149   0.881124  0.608700   0.363453    0.206265
# ...

# %% [markdown]
# 1 b ) The initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.725733  3.088911  1.732230
# 1   1.668078  2.924842  1.673910
# 2   1.612832  2.777194  1.618110
# 3   1.668078  2.924842  1.673910
# 4   2.916176  4.323152  2.920983
# 5   1.664558  2.430072  1.666981
# 6   1.161347  1.688742  1.162973
# 7   0.891163  1.293671  0.892389
# 8   0.722797  1.048298  0.723782
# 9   0.607877  0.881124  0.608700
# 10  0.524459  0.759917  0.525166
# 11  0.461159  0.668014  0.461779
# 12  2.911841  4.316336  2.916637
# 13  1.663108  2.427905  1.665528
# 14  1.160635  1.687693  1.162260
# 15  0.890743  1.293054  0.891968
# 16  0.722520  1.047893  0.723504
# 17  0.607680  0.880838  0.608503
# 18  0.524313  0.759704  0.525019
# 19  0.461046  0.667849  0.461666
# 20  2.916176  4.323152  2.920983
# 21  1.664558  2.430072  1.666981
# 22  1.161347  1.688742  1.162973
# 23  0.891163  1.293671  0.892389
# 24  0.722797  1.048298  0.723782
# 25  0.607877  0.881124  0.608700
# 26  0.524459  0.759917  0.525166

# %% [markdown]
# 1 c ) The initial symmetrical short-circuit current and the equivalent thermal short-circuit current at each line and node are almost same(Kilo Amperes with small difference). The short-circuit current peak values is around 1.8 times higher than the initial symmetrical and equivalent thermal short-circuit current. The difference in the current is clearly shown in above table.

# %% [markdown]
# 1 d) Which standard is used to compute the short-circuit currents? Briefly explain
# the methodology based on the documentation.

# %% [markdown]
# The calculation is based on the method of the equivalent voltage source according to DIN/IEC EN 60909. The initial short-circuit alternating current ikss is the basis of the short-circuit calculation and is therefore always calculated. Other short-circuit currents can be calculated from ikss with the conversion factors defined in DIN/IEC EN 60909.
#
# The output is stored in the net.res_bus_sc table as a short_circuit current for each bus.

# %% [markdown]
# 2) Deactivating the contribution of the large motor and re-computing the maximum three phase short-circuit currents for a solid fault (ZF=0 Ω).

# %%
net.sgen.in_service=False

# %%
pp.shortcircuit.calc_sc(net, case='max', ip=True, ith=True, branch_results=True)
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers

# %% [markdown]
# 2 a) Presenting the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each bus.

# %%
net.res_bus_sc
# Out:
#      ikss_ka     skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.524864  100.000000   1.011668  0.527447  43.969642  125.627547
# 1   2.044769   70.832867   4.280510  2.058661   1.517492    6.023599
# 2   1.725733   59.781143   3.088911  1.732230   3.082492    6.683599
# 3   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 4   1.612832   55.870123   2.777194  1.618110   3.708492    6.947599
# 5   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 6   9.335478    6.467809  19.207832  9.394547   0.007113    0.026265
# 7   2.916176    2.020386   4.323152  2.920983   0.066503    0.056265
# 8   1.664558    1.153240   2.430072  1.666981   0.125893    0.086265
# 9   1.161347    0.804605   1.688742  1.162973   0.185283    0.116265
# 10  0.891163    0.617416   1.293671  0.892389   0.244673    0.146265
# 11  0.722797    0.500768   1.048298  0.723782   0.304063    0.176265
# 12  0.607877    0.421149   0.881124  0.608700   0.363453    0.206265
# ...

# %% [markdown]
# 2 b) Presenting the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.725733  3.088911  1.732230
# 1   1.668078  2.924842  1.673910
# 2   1.612832  2.777194  1.618110
# 3   1.668078  2.924842  1.673910
# 4   2.916176  4.323152  2.920983
# 5   1.664558  2.430072  1.666981
# 6   1.161347  1.688742  1.162973
# 7   0.891163  1.293671  0.892389
# 8   0.722797  1.048298  0.723782
# 9   0.607877  0.881124  0.608700
# 10  0.524459  0.759917  0.525166
# 11  0.461159  0.668014  0.461779
# 12  2.911841  4.316336  2.916637
# 13  1.663108  2.427905  1.665528
# 14  1.160635  1.687693  1.162260
# 15  0.890743  1.293054  0.891968
# 16  0.722520  1.047893  0.723504
# 17  0.607680  0.880838  0.608503
# 18  0.524313  0.759704  0.525019
# 19  0.461046  0.667849  0.461666
# 20  2.916176  4.323152  2.920983
# 21  1.664558  2.430072  1.666981
# 22  1.161347  1.688742  1.162973
# 23  0.891163  1.293671  0.892389
# 24  0.722797  1.048298  0.723782
# 25  0.607877  0.881124  0.608700
# 26  0.524459  0.759917  0.525166

# %% [markdown]
# 2 c) Comparing to the values of Task 1 and explaining the difference.

# %% [markdown]
# The initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line and bus are same, eventhough deactivating the large Motor.

# %% [markdown]
# 3) Computing the maximum three-phase short-circuit currents with fault impedance
# ZF=1+j1.5 Ω.

# %%
net.sgen.in_service=True

# %%
pp.shortcircuit.calc_sc(net, case='max', ip=True, ith=True,r_fault_ohm=1,x_fault_ohm=1.5,branch_results=True)
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers

# %% [markdown]
# 3 a) Presenting the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.388865  2.598556  1.394997
# 1   1.350409  2.485218  1.356026
# 2   1.313356  2.380546  1.318528
# 3   1.350409  2.485218  1.356026
# 4   0.134649  0.274747  0.135473
# 5   0.130594  0.263421  0.131358
# 6   0.126745  0.252853  0.127455
# 7   0.123089  0.242981  0.123751
# 8   0.119614  0.233748  0.120234
# 9   0.116310  0.225102  0.116891
# 10  0.113166  0.216995  0.113712
# 11  0.110172  0.209386  0.110687
# 12  0.134641  0.274724  0.135465
# 13  0.130586  0.263398  0.131350
# 14  0.126737  0.252832  0.127447
# 15  0.123082  0.242961  0.123744
# 16  0.119607  0.233730  0.120227
# 17  0.116304  0.225085  0.116885
# 18  0.113160  0.216980  0.113706
# 19  0.110166  0.209371  0.110681
# 20  0.134649  0.274747  0.135473
# 21  0.130594  0.263421  0.131358
# 22  0.126745  0.252853  0.127455
# 23  0.123089  0.242981  0.123751
# 24  0.119614  0.233748  0.120234
# 25  0.116310  0.225102  0.116891
# 26  0.113166  0.216995  0.113712

# %% [markdown]
# 3 b) Presenting the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each bus.

# %%
net.res_bus_sc
# Out:
#      ikss_ka    skss_mw     ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.518064  98.704543  1.000390  0.520631  44.969642  127.127547
# 1   1.600998  55.460188  3.333988  1.611640   2.517492    7.523599
# 2   1.388865  48.111706  2.598556  1.394997   4.082492    8.183599
# 3   1.350409  46.779523  2.485218  1.356026   4.395492    8.315599
# 4   1.313356  45.495973  2.380546  1.318528   4.708492    8.447599
# 5   1.350409  46.779523  2.485218  1.356026   4.395492    8.315599
# 6   0.138923   0.096249  0.286901  0.139815   1.007113    1.526265
# 7   0.134649   0.093288  0.274747  0.135473   1.066503    1.556265
# 8   0.130594   0.090478  0.263421  0.131358   1.125893    1.586265
# 9   0.126745   0.087811  0.252853  0.127455   1.185283    1.616265
# 10  0.123089   0.085278  0.242981  0.123751   1.244673    1.646265
# 11  0.119614   0.082871  0.233748  0.120234   1.304063    1.676265
# 12  0.116310   0.080582  0.225102  0.116891   1.363453    1.706265
# ...

# %% [markdown]
# 3 c) Comparing to the values of Task 1 and explaining the difference.

# %% [markdown]
# In both cases, (line and bus) the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current are slightly decreased.But, the Resistance and the Reactance are increased at the buses.

# %% [markdown]
# 4 ) Computing the maximum two-phase short-circuit currents for a solid fault (ZF=0 Ω).

# %%
pp.shortcircuit.calc_sc(net,fault="2ph", case='max', ip=True, ith=True,branch_results=True)
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers

# %% [markdown]
# 4 a) Present the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line.

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.494529  2.675075  1.500155
# 1   1.444598  2.532987  1.449648
# 2   1.396753  2.405121  1.401325
# 3   1.444598  2.532987  1.449648
# 4   2.525483  3.743959  2.529645
# 5   1.441550  2.104504  1.443648
# 6   1.005756  1.462494  1.007164
# 7   0.771770  1.120352  0.772832
# 8   0.625960  0.907853  0.626813
# 9   0.526437  0.763076  0.527149
# 10  0.454195  0.658107  0.454807
# 11  0.399376  0.578517  0.399912
# 12  2.521728  3.738057  2.525882
# 13  1.440293  2.102628  1.442389
# 14  1.005140  1.461585  1.006547
# 15  0.771406  1.119818  0.772467
# 16  0.625720  0.907502  0.626573
# 17  0.526267  0.762828  0.526979
# 18  0.454068  0.657923  0.454680
# 19  0.399278  0.578374  0.399814
# 20  2.525483  3.743959  2.529645
# 21  1.441550  2.104504  1.443648
# 22  1.005756  1.462494  1.007164
# 23  0.771770  1.120352  0.772832
# 24  0.625960  0.907853  0.626813
# 25  0.526437  0.763076  0.527149
# 26  0.454195  0.658107  0.454807

# %% [markdown]
# 4 b) Present the initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each bus

# %%
net.res_bus_sc
# Out:
#      ikss_ka    skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.454545  28.867513   0.876130  0.456782  43.969642  125.627547
# 1   1.770822  20.447687   3.707030  1.782853   1.517492    6.023599
# 2   1.494529  17.257330   2.675075  1.500155   3.082492    6.683599
# 3   1.444598  16.680780   2.532987  1.449648   3.395492    6.815599
# 4   1.396753  16.128315   2.405121  1.401325   3.708492    6.947599
# 5   1.444598  16.680780   2.532987  1.449648   3.395492    6.815599
# 6   8.084761   1.867096  16.634470  8.135916   0.007113    0.026265
# 7   2.525483   0.583235   3.743959  2.529645   0.066503    0.056265
# 8   1.441550   0.332912   2.104504  1.443648   0.125893    0.086265
# 9   1.005756   0.232269   1.462494  1.007164   0.185283    0.116265
# 10  0.771770   0.178233   1.120352  0.772832   0.244673    0.146265
# 11  0.625960   0.144559   0.907853  0.626813   0.304063    0.176265
# 12  0.526437   0.121575   0.763076  0.527149   0.363453    0.206265
# ...

# %% [markdown]
# 4 c) Comparing to the values of Task 1 and explaining the difference.

# %% [markdown]
# At lines:
#     The initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each line are decreased.
#
# At buses:
#     Resistance and Reactance remains un changed.
#     The initial symmetrical short-circuit current, the short-circuit current
# peak, and the equivalent thermal short-circuit current at each bus are decreased slightly.
#     But the initial symmetric power is almost decreased by 75%.

# %% [markdown]
# # # Color Mapping

# %% [markdown]
# I tried coloring mapping part, but the output didn't came.

# %% [markdown]
# 2 b) Creating and displaying a colormap of the buses showing blue for all voltages below
# 0.95, green for voltages between 0.95 and 1.05, and red for all voltages above
# 1.05 pu.

# %%
cmap_list= [((0,0.95), "blue"),((0.95,1.05),"green"),((1.05,1.1), "red") ]
cmap, norm=plot.cmap_discrete(cmap_list)
bc= plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc= plot.create_line_collection(net)

plot.draw_collection([lc, bc], figsize=(8,6))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13384/1105211913.py in <module>
#       1 cmap_list= [((0,0.95), "blue"),((0.95,1.05),"green"),((1.05,1.1), "red") ]
#       2 cmap, norm=plot.cmap_discrete(cmap_list)
# ----> 3 bc= plot.create_bus_collection(net, net.bus.index, size=0.1,zorder=2, cmap=cmap, norm=norm)
#       4 lc= plot.create_line_collection(net)
#       5 bus_geodata = net["bus_geodata"]
#
# ~\anaconda3\lib\site-packages\pandapower\plotting\collections.py in create_bus_collection(net, buses, size, patch_type, color, z, cmap, norm, infofunc, picker, bus_geodata, cbar_title, **kwargs)
#     378         bus_geodata = net["bus_geodata"]
#     379
# --> 380     coords = list(zip(bus_geodata.loc[buses, "x"].values, bus_geodata.loc[buses, "y"].values))
#     381
# ...

# %% [markdown]
# 3 b) Creating and displaying a colormap of the buses showing blue for all voltages below
# 0.95, green for voltages between 0.95 and 1.05, and red for all voltages above
# 1.05 pu.

# %%
cmap_list= [((0,0.95), "blue"),((0.95,1.05),"green"),((1.05,1.1), "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)

plot.draw_collection([bc], figsize=(8,6))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13384/2365708135.py in <module>
#       1 cmap_list= [((0,0.95), "blue"),((0.95,1.05),"green"),((1.05,1.1), "red")]
#       2 cmap, norm = plot.cmap_discrete(cmap_list)
# ----> 3 bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
#       4
#       5 plot.draw_collection([bc], figsize=(8,6))
#
# ~\anaconda3\lib\site-packages\pandapower\plotting\collections.py in create_bus_collection(net, buses, size, patch_type, color, z, cmap, norm, infofunc, picker, bus_geodata, cbar_title, **kwargs)
#     378         bus_geodata = net["bus_geodata"]
#     379
# --> 380     coords = list(zip(bus_geodata.loc[buses, "x"].values, bus_geodata.loc[buses, "y"].values))
#     381
#     382     infos = [infofunc(bus) for bus in buses] if infofunc is not None else []
#
# ...
