# %% [markdown]
# 1)
#
# a. NA2XS2Y 1*95 RM/25 12/20KV cable is used for 20KV lines.
#    It is a Aluminium Conductor cable, where r is the round conductor form and m is multi-wire conductor and it is Cross-linked Polyethylen.
#    It's nominal voltage is 12/20(24) kV. Temperature Range -40C to +90C.
#    Yes, it is typical for MV Systems because Medium Voltage Systems range is from 1kV to 35kV.

# %% [markdown]
# b. 48-AL1/8-ST1A 0.4 cable is used for 400V lines.
#    It is a Aluminium Steel Reinforced cable. Its cross section is 56.3 mm*mm.
#    It has a total fo 7 wires in which 6 are Aluminium and one is steel. its rated strength is 16.81kN.
#    Yes, it is typical for LV systems beacause Low Voltage systems range is from 50V to 1000V.

# %% [markdown]
# c. It is a Radial Feeeder System. it si typical for distribution System because
#    1. These are the simplest ones.
#    2. Initial Cost is low.
#    3. Requires less amount fo cables.
#    4. It has low maintainence.

# %%
import pandapower as pp

net = pp.create_empty_network()

# %%
bus1 = pp.create_bus(net, name="HV Transformer Bus", vn_kv=110, type="n")
bus2 = pp.create_bus(net, name="MV Main Bus", vn_kv=20, type="n")
bus3 = pp.create_bus(net, name="MV Bus 1", vn_kv=20, type="n")
bus4 = pp.create_bus(net, name="MV Bus 2", vn_kv=20, type="n")
bus5 = pp.create_bus(net, name="MV Bus 3", vn_kv=20, type="n")
bus6 = pp.create_bus(net, name="MV Bus 4", vn_kv=20, type="n")
bus41 = pp.create_bus(net, name="LV Bus 41", vn_kv=0.4, type="n")
bus51 = pp.create_bus(net, name="LV Bus 51", vn_kv=0.4, type="n")
bus61 = pp.create_bus(net, name="LV Bus 61", vn_kv=0.4, type="n")

net.bus
# Out:
#                  name  vn_kv type  zone  in_service
# 0  HV Transformer Bus  110.0    n  None        True
# 1         MV Main Bus   20.0    n  None        True
# 2            MV Bus 1   20.0    n  None        True
# 3            MV Bus 2   20.0    n  None        True
# 4            MV Bus 3   20.0    n  None        True
# 5            MV Bus 4   20.0    n  None        True
# 6           LV Bus 41    0.4    n  None        True
# 7           LV Bus 51    0.4    n  None        True
# 8           LV Bus 61    0.4    n  None        True

# %%
pp.create_ext_grid(net, bus1, s_sc_max_mva=100, s_sc_min_mva=80, rx_max=0.35, rx_min=0.20)

net.ext_grid
# Out:
#    name  bus  vm_pu  va_degree  in_service  s_sc_max_mva  s_sc_min_mva  \
# 0  None    0    1.0        0.0        True         100.0          80.0
#
#    rx_min  rx_max
# 0     0.2    0.35

# %%
trafo1 = pp.create_transformer(net, bus1, bus2, name="transformer1", std_type="25 MVA 110/20 kV")
trafo2 = pp.create_transformer(net, bus4, bus41, name="transformer2", std_type="0.4 MVA 20/0.4 kV")
trafo3 = pp.create_transformer(net, bus5, bus51, name="transformer3", std_type="0.4 MVA 20/0.4 kV")
trafo4 = pp.create_transformer(net, bus6, bus61, name="transformer4", std_type="0.4 MVA 20/0.4 kV")

net.trafo
# Out:
#            name           std_type  hv_bus  lv_bus  sn_mva  vn_hv_kv  \
# 0  transformer1   25 MVA 110/20 kV       0       1    25.0     110.0
# 1  transformer2  0.4 MVA 20/0.4 kV       3       6     0.4      20.0
# 2  transformer3  0.4 MVA 20/0.4 kV       4       7     0.4      20.0
# 3  transformer4  0.4 MVA 20/0.4 kV       5       8     0.4      20.0
#
#    vn_lv_kv  vk_percent  vkr_percent  pfe_kw  ...  tap_neutral  tap_min  \
# 0      20.0        12.0        0.410   14.00  ...            0       -9
# 1       0.4         6.0        1.425    1.35  ...            0       -2
# 2       0.4         6.0        1.425    1.35  ...            0       -2
# 3       0.4         6.0        1.425    1.35  ...            0       -2
#
#   tap_max  tap_step_percent  tap_step_degree  tap_pos  tap_phase_shifter  \
# 0       9               1.5              0.0        0              False
# 1       2               2.5              0.0        0              False
# ...

# %%
line1 = pp.create_line(net, bus2, bus3, length_km=5, std_type="NA2XS2Y 1x95 RM/25 12/20 kV",  name="Line 1")
line2 = pp.create_line(net, bus2, bus4, length_km=6, std_type="NA2XS2Y 1x95 RM/25 12/20 kV",  name="Line 2")
line3 = pp.create_line(net, bus2, bus5, length_km=7, std_type="NA2XS2Y 1x95 RM/25 12/20 kV",  name="Line 3")
line4 = pp.create_line(net, bus2, bus6, length_km=6, std_type="NA2XS2Y 1x95 RM/25 12/20 kV",  name="Line 4")

# %%
net.line
# Out:
#      name                     std_type  from_bus  to_bus  length_km  \
# 0  Line 1  NA2XS2Y 1x95 RM/25 12/20 kV         1       2        5.0
# 1  Line 2  NA2XS2Y 1x95 RM/25 12/20 kV         1       3        6.0
# 2  Line 3  NA2XS2Y 1x95 RM/25 12/20 kV         1       4        7.0
# 3  Line 4  NA2XS2Y 1x95 RM/25 12/20 kV         1       5        6.0
#
#    r_ohm_per_km  x_ohm_per_km  c_nf_per_km  g_us_per_km  max_i_ka   df  \
# 0         0.313         0.132        216.0          0.0     0.252  1.0
# 1         0.313         0.132        216.0          0.0     0.252  1.0
# 2         0.313         0.132        216.0          0.0     0.252  1.0
# 3         0.313         0.132        216.0          0.0     0.252  1.0
#
#    parallel type  in_service
# 0         1   cs        True
# 1         1   cs        True
# 2         1   cs        True
# 3         1   cs        True

# %%
pp.create_sgen(net, bus3, p_mw=3, q_mvar=1, sn_mva=10, name="M3", k=1.2, rx=7)

net.sgen
# Out:
#   name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  current_source  \
# 0   M3    2   3.0     1.0    10.0      1.0        True  wye            True
#
#      k   rx
# 0  1.2  7.0

# %%
bus42 = pp.create_bus(net, name="LV Bus 42", vn_kv=0.4, type="b")
bus43 = pp.create_bus(net, name="LV Bus 43", vn_kv=0.4, type="b")
bus44 = pp.create_bus(net, name="LV Bus 44", vn_kv=0.4, type="b")
bus45 = pp.create_bus(net, name="LV Bus 45", vn_kv=0.4, type="b")
bus46 = pp.create_bus(net, name="LV Bus 46", vn_kv=0.4, type="b")
bus47 = pp.create_bus(net, name="LV Bus 47", vn_kv=0.4, type="b")
bus48 = pp.create_bus(net, name="LV Bus 48", vn_kv=0.4, type="b")
bus49 = pp.create_bus(net, name="LV Bus 49", vn_kv=0.4, type="b")
bus52 = pp.create_bus(net, name="LV Bus 52", vn_kv=0.4, type="b")
bus53 = pp.create_bus(net, name="LV Bus 53", vn_kv=0.4, type="b")
bus54 = pp.create_bus(net, name="LV Bus 54", vn_kv=0.4, type="b")
bus55 = pp.create_bus(net, name="LV Bus 55", vn_kv=0.4, type="b")
bus56 = pp.create_bus(net, name="LV Bus 56", vn_kv=0.4, type="b")
bus57 = pp.create_bus(net, name="LV Bus 57", vn_kv=0.4, type="b")
bus58 = pp.create_bus(net, name="LV Bus 58", vn_kv=0.4, type="b")
bus59 = pp.create_bus(net, name="LV Bus 59", vn_kv=0.4, type="b")
bus62 = pp.create_bus(net, name="LV Bus 62", vn_kv=0.4, type="b")
bus63 = pp.create_bus(net, name="LV Bus 63", vn_kv=0.4, type="b")
bus64 = pp.create_bus(net, name="LV Bus 64", vn_kv=0.4, type="b")
bus65 = pp.create_bus(net, name="LV Bus 65", vn_kv=0.4, type="b")
bus66 = pp.create_bus(net, name="LV Bus 66", vn_kv=0.4, type="b")
bus67 = pp.create_bus(net, name="LV Bus 67", vn_kv=0.4, type="b")
bus68 = pp.create_bus(net, name="LV Bus 68", vn_kv=0.4, type="b")
bus69 = pp.create_bus(net, name="LV Bus 69", vn_kv=0.4, type="b")

net.bus
# Out:
#                   name  vn_kv type  zone  in_service
# 0   HV Transformer Bus  110.0    n  None        True
# 1          MV Main Bus   20.0    n  None        True
# 2             MV Bus 1   20.0    n  None        True
# 3             MV Bus 2   20.0    n  None        True
# 4             MV Bus 3   20.0    n  None        True
# 5             MV Bus 4   20.0    n  None        True
# 6            LV Bus 41    0.4    n  None        True
# 7            LV Bus 51    0.4    n  None        True
# 8            LV Bus 61    0.4    n  None        True
# 9            LV Bus 42    0.4    b  None        True
# 10           LV Bus 43    0.4    b  None        True
# 11           LV Bus 44    0.4    b  None        True
# 12           LV Bus 45    0.4    b  None        True
# 13           LV Bus 46    0.4    b  None        True
# 14           LV Bus 47    0.4    b  None        True
# 15           LV Bus 48    0.4    b  None        True
# 16           LV Bus 49    0.4    b  None        True
# ...

# %%
line1 = pp.create_line(net, bus41, bus42, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 1")
line2 = pp.create_line(net, bus42, bus43, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 2")
line3 = pp.create_line(net, bus43, bus44, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 3")
line4 = pp.create_line(net, bus44, bus45, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 4")
line5 = pp.create_line(net, bus45, bus46, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 5")
line6 = pp.create_line(net, bus46, bus47, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 6")
line7 = pp.create_line(net, bus47, bus48, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 7")
line8 = pp.create_line(net, bus48, bus49, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 8")
line9 = pp.create_line(net, bus51, bus52, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 9")
line10 = pp.create_line(net, bus52, bus53, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 10")
line11 = pp.create_line(net, bus53, bus54, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 11")
line12 = pp.create_line(net, bus54, bus55, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 12")
line13 = pp.create_line(net, bus55, bus56, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 13")
line14 = pp.create_line(net, bus56, bus57, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 14")
line15 = pp.create_line(net, bus57, bus58, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 15")
line16 = pp.create_line(net, bus58, bus59, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 16")
line17 = pp.create_line(net, bus61, bus62, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 17")
line18 = pp.create_line(net, bus62, bus63, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 18")
line19 = pp.create_line(net, bus63, bus64, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 19")
line20 = pp.create_line(net, bus64, bus65, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 20")
line21 = pp.create_line(net, bus65, bus66, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 21")
line22 = pp.create_line(net, bus66, bus67, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 22")
line23 = pp.create_line(net, bus67, bus68, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 23")
line24 = pp.create_line(net, bus68, bus69, length_km=0.1, std_type="48-AL1/8-ST1A 0.4",  name="line 24")

net.line
# Out:
#        name                     std_type  from_bus  to_bus  length_km  \
# 0    Line 1  NA2XS2Y 1x95 RM/25 12/20 kV         1       2        5.0
# 1    Line 2  NA2XS2Y 1x95 RM/25 12/20 kV         1       3        6.0
# 2    Line 3  NA2XS2Y 1x95 RM/25 12/20 kV         1       4        7.0
# 3    Line 4  NA2XS2Y 1x95 RM/25 12/20 kV         1       5        6.0
# 4    line 1            48-AL1/8-ST1A 0.4         6       9        0.1
# 5    line 2            48-AL1/8-ST1A 0.4         9      10        0.1
# 6    line 3            48-AL1/8-ST1A 0.4        10      11        0.1
# 7    line 4            48-AL1/8-ST1A 0.4        11      12        0.1
# 8    line 5            48-AL1/8-ST1A 0.4        12      13        0.1
# 9    line 6            48-AL1/8-ST1A 0.4        13      14        0.1
# 10   line 7            48-AL1/8-ST1A 0.4        14      15        0.1
# 11   line 8            48-AL1/8-ST1A 0.4        15      16        0.1
# ...

# %%
pp.create_load_from_cosphi(net, bus42, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus43, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus44, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus45, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus46, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus47, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus48, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus49, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus52, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus53, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus54, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus55, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus56, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus57, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus58, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus59, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus62, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus63, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus64, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus65, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus66, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus67, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus68, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus69, sn_mva=0.002315, cos_phi=0.95, mode="underexcited")

net.load
# Out:
#     name  bus      p_mw    q_mvar  const_z_percent  const_i_percent    sn_mva  \
# 0   None    9  0.002199  0.000723              0.0              0.0  0.002315
# 1   None   10  0.002199  0.000723              0.0              0.0  0.002315
# 2   None   11  0.002199  0.000723              0.0              0.0  0.002315
# 3   None   12  0.002199  0.000723              0.0              0.0  0.002315
# 4   None   13  0.002199  0.000723              0.0              0.0  0.002315
# 5   None   14  0.002199  0.000723              0.0              0.0  0.002315
# 6   None   15  0.002199  0.000723              0.0              0.0  0.002315
# 7   None   16  0.002199  0.000723              0.0              0.0  0.002315
# 8   None   17  0.002199  0.000723              0.0              0.0  0.002315
# 9   None   18  0.002199  0.000723              0.0              0.0  0.002315
# 10  None   19  0.002199  0.000723              0.0              0.0  0.002315
# ...

# %%
pp.runpp(net)
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.887741  1.567016
# 1   1.008109   0.774632  0.000000  0.000000
# 2   1.021331   0.816956 -3.000000 -1.000000
# 3   1.008169   0.752162  0.000000  0.000000
# 4   1.008211   0.744156  0.000000  0.000000
# 5   1.008169   0.752162  0.000000  0.000000
# 6   1.006637   0.610370  0.000000  0.000000
# 7   1.006678   0.602376  0.000000  0.000000
# 8   1.006637   0.610370  0.000000  0.000000
# 9   0.998876   0.544698  0.002199  0.000723
# 10  0.992070   0.486391  0.002199  0.000723
# 11  0.986224   0.435772  0.002199  0.000723
# 12  0.981345   0.393130  0.002199  0.000723
# 13  0.977435   0.358709  0.002199  0.000723
# 14  0.974500   0.332712  0.002199  0.000723
# 15  0.972541   0.315293  0.002199  0.000723
# 16  0.971561   0.306558  0.002199  0.000723
# 17  0.998918   0.536709  0.002199  0.000723
# 18  0.992113   0.478407  0.002199  0.000723
# 19  0.986267   0.427793  0.002199  0.000723
# ...

# %% [markdown]
# From the above table you can see that the Load is 2KW

# %%
#import pandapower as pp
import pandapower.plotting as plot
# %matplotlib inline

# %%
net.bus_geodata.drop(net.bus_geodata.index, inplace=True)
net.line_geodata.drop(net.line_geodata.index, inplace=True)
plot.create_generic_coordinates(net, respect_switches=True)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (33 elements)
#    - load (24 elements)
#    - sgen (1 element)
#    - ext_grid (1 element)
#    - line (28 elements)
#    - trafo (4 elements)
#    - bus_geodata (33 elements)
#  and the following results tables:
#    - res_bus (33 elements)
#    - res_line (28 elements)
#    - res_trafo (4 elements)
#    - res_ext_grid (1 element)
#    - res_load (24 elements)
#    - res_sgen (1 element)

# %%
cmap_list=[((0, 0.95), "blue"), ((0.95, 1.05), "green"), ((1.05, 1.1), "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc = plot.create_line_collection(net)
plot.draw_collections([lc, bc], figsize=(8,6))
# Out:
# use_bus_geodata is automatically set to True, since net.line_geodata is empty.
# <AxesSubplot:>

# %% [markdown]
# TASK 2
#
# 3) EVERY HOUSEHOLD IS INCREASED TO 4KW AT 0.95 POWER FACTOR

# %%
pp.create_load_from_cosphi(net, bus42, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus43, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus44, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus45, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus46, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus47, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus48, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus49, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus52, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus53, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus54, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus55, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus56, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus57, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus58, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus59, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus62, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus63, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus64, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus65, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus66, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus67, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus68, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus69, sn_mva=0.0019, cos_phi=0.95, mode="underexcited")

net.load
# Out:
#     name  bus      p_mw    q_mvar  const_z_percent  const_i_percent    sn_mva  \
# 0   None    9  0.002199  0.000723              0.0              0.0  0.002315
# 1   None   10  0.002199  0.000723              0.0              0.0  0.002315
# 2   None   11  0.002199  0.000723              0.0              0.0  0.002315
# 3   None   12  0.002199  0.000723              0.0              0.0  0.002315
# 4   None   13  0.002199  0.000723              0.0              0.0  0.002315
# 5   None   14  0.002199  0.000723              0.0              0.0  0.002315
# 6   None   15  0.002199  0.000723              0.0              0.0  0.002315
# 7   None   16  0.002199  0.000723              0.0              0.0  0.002315
# 8   None   17  0.002199  0.000723              0.0              0.0  0.002315
# 9   None   18  0.002199  0.000723              0.0              0.0  0.002315
# 10  None   19  0.002199  0.000723              0.0              0.0  0.002315
# ...

# %%
pp.runpp(net)
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw    q_mvar
# 0   1.000000   0.000000  2.841198  1.552127
# 1   1.008027   0.762142  0.000000  0.000000
# 2   1.021250   0.804474 -3.000000 -1.000000
# 3   1.008004   0.739373  0.000000  0.000000
# 4   1.008032   0.731318  0.000000  0.000000
# 5   1.008004   0.739373  0.000000  0.000000
# 6   1.005147   0.480282  0.000000  0.000000
# 7   1.005175   0.472241  0.000000  0.000000
# 8   1.005147   0.480282  0.000000  0.000000
# 9   0.990668   0.359548  0.004004  0.001316
# 10  0.977942   0.250968  0.004004  0.001316
# 11  0.966991   0.155620  0.004004  0.001316
# 12  0.957835   0.074496  0.004004  0.001316
# 13  0.950490   0.008470  0.004004  0.001316
# 14  0.944969  -0.041723  0.004004  0.001316
# 15  0.941283  -0.075513  0.004004  0.001316
# 16  0.939438  -0.092506  0.004004  0.001316
# 17  0.990696   0.351515  0.004004  0.001316
# 18  0.977970   0.242941  0.004004  0.001316
# 19  0.967020   0.147599  0.004004  0.001316
# ...

# %% [markdown]
# Here from the above table you can see that the Load is increased to 4KW

# %%
import pandapower.plotting as plot
# %matplotlib inline

# %%
net.bus_geodata.drop(net.bus_geodata.index, inplace=True)
net.line_geodata.drop(net.line_geodata.index, inplace=True)
plot.create_generic_coordinates(net, respect_switches=True)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (33 elements)
#    - load (48 elements)
#    - sgen (1 element)
#    - ext_grid (1 element)
#    - line (28 elements)
#    - trafo (4 elements)
#    - bus_geodata (33 elements)
#  and the following results tables:
#    - res_bus (33 elements)
#    - res_line (28 elements)
#    - res_trafo (4 elements)
#    - res_ext_grid (1 element)
#    - res_load (48 elements)
#    - res_sgen (1 element)

# %%
cmap_list=[((0, 0.95), "blue"), ((0.95, 1.05), "green"), ((1.05, 1.1), "red")]
cmap, norm = plot.cmap_discrete(cmap_list)
bc = plot.create_bus_collection(net, net.bus.index, size=0.1, zorder=2, cmap=cmap, norm=norm)
lc = plot.create_line_collection(net)
plot.draw_collections([lc, bc], figsize=(8,6))
# Out:
# use_bus_geodata is automatically set to True, since net.line_geodata is empty.
# <AxesSubplot:>

# %% [markdown]
# TASK 2
#
# 4) HOUSE WILL PURCHASE AN ELECTRIC VEHICLE WITH A 7KW CHARGER

# %%
pp.create_load_from_cosphi(net, bus42, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus43, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus44, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus45, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus46, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus47, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus48, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus49, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus52, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus53, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus54, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus55, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus56, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus57, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus58, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus59, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus62, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus63, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus64, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus65, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus66, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus67, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus68, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")
pp.create_load_from_cosphi(net, bus69, sn_mva=0.0052, cos_phi=0.95, mode="underexcited")

net.load
# Out:
#     name  bus      p_mw    q_mvar  const_z_percent  const_i_percent    sn_mva  \
# 0   None    9  0.002199  0.000723              0.0              0.0  0.002315
# 1   None   10  0.002199  0.000723              0.0              0.0  0.002315
# 2   None   11  0.002199  0.000723              0.0              0.0  0.002315
# 3   None   12  0.002199  0.000723              0.0              0.0  0.002315
# 4   None   13  0.002199  0.000723              0.0              0.0  0.002315
# ..   ...  ...       ...       ...              ...              ...       ...
# 67  None   28  0.004940  0.001624              0.0              0.0  0.005200
# 68  None   29  0.004940  0.001624              0.0              0.0  0.005200
# 69  None   30  0.004940  0.001624              0.0              0.0  0.005200
# 70  None   31  0.004940  0.001624              0.0              0.0  0.005200
# 71  None   32  0.004940  0.001624              0.0              0.0  0.005200
#
#     scaling  in_service type
# ...

# %%
pp.runpp(net)

# %%
net
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (33 elements)
#    - load (72 elements)
#    - sgen (1 element)
#    - ext_grid (1 element)
#    - line (28 elements)
#    - trafo (4 elements)
#    - bus_geodata (33 elements)
#  and the following results tables:
#    - res_bus (33 elements)
#    - res_line (28 elements)
#    - res_trafo (4 elements)
#    - res_ext_grid (1 element)
#    - res_load (72 elements)
#    - res_sgen (1 element)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree      p_mw   q_mvar
# 0   1.000000   0.000000  2.699926  1.50327
# 1   1.007761   0.724264  0.000000  0.00000
# 2   1.020987   0.766626 -3.000000 -1.00000
# 3   1.007484   0.700900  0.000000  0.00000
# 4   1.007469   0.692748  0.000000  0.00000
# 5   1.007484   0.700900  0.000000  0.00000
# 6   1.000460   0.085797  0.000000  0.00000
# 7   1.000445   0.077625  0.000000  0.00000
# 8   1.000460   0.085797  0.000000  0.00000
# 9   0.965382  -0.192232  0.008944  0.00294
# 10  0.934336  -0.452724  0.008944  0.00294
# 11  0.907451  -0.690256  0.008944  0.00294
# 12  0.884846  -0.899270  0.008944  0.00294
# 13  0.866626  -1.074359  0.008944  0.00294
# 14  0.852880  -1.210596  0.008944  0.00294
# 15  0.843676  -1.303892  0.008944  0.00294
# 16  0.839062  -1.351308  0.008944  0.00294
# 17  0.965367  -0.200413  0.008944  0.00294
# 18  0.934320  -0.460913  0.008944  0.00294
# 19  0.907435  -0.698454  0.008944  0.00294
# 20  0.884829  -0.907476  0.008944  0.00294
# ...

# %% [markdown]
# 4. a) Here the Load is increased to 9KW here its showing 8.944.
#       YES, the System is able to withstand this Load.

# %%
net.res_line
# Out:
#     p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  \
# 0   -2.961917    -1.123592  3.000000   1.000000  0.038083 -0.123592
# 1    0.082097    -0.136260 -0.082053  -0.029074  0.000044 -0.165334
# 2    0.082114    -0.163809 -0.082053  -0.029074  0.000061 -0.192883
# 3    0.082097    -0.136260 -0.082053  -0.029074  0.000044 -0.165334
# 4    0.080430     0.028002 -0.077740  -0.026643  0.002690  0.001359
# 5    0.068796     0.023703 -0.066687  -0.022638  0.002109  0.001065
# 6    0.057743     0.019698 -0.056160  -0.018899  0.001583  0.000799
# 7    0.047216     0.015959 -0.046096  -0.015394  0.001120  0.000566
# 8    0.037152     0.012454 -0.036424  -0.012086  0.000728  0.000368
# 9    0.027480     0.009146 -0.027065  -0.008937  0.000415  0.000209
# 10   0.018121     0.005997 -0.017935  -0.005903  0.000186  0.000094
# 11   0.008991     0.002963 -0.008944  -0.002940  0.000047  0.000024
# 12   0.080431     0.028002 -0.077741  -0.026643  0.002690  0.001359
# ...

# %%
net.res_trafo
# Out:
#     p_hv_mw  q_hv_mvar   p_lv_mw  q_lv_mvar     pl_mw   ql_mvar   i_hv_ka  \
# 0 -2.699926  -1.503270  2.715609   1.559920  0.015683  0.056650  0.016219
# 1  0.082053   0.029074 -0.080430  -0.028002  0.001623  0.001072  0.002494
# 2  0.082053   0.029074 -0.080431  -0.028002  0.001623  0.001072  0.002494
# 3  0.082053   0.029074 -0.080430  -0.028002  0.001623  0.001072  0.002494
#
#     i_lv_ka  vm_hv_pu  va_hv_degree  vm_lv_pu  va_lv_degree  loading_percent
# 0  0.089710  1.000000      0.000000  1.007761      0.724264        12.430542
# 1  0.122869  1.007484      0.700900  1.000460      0.085797        21.601209
# 2  0.122871  1.007469      0.692748  1.000445      0.077625        21.601619
# 3  0.122869  1.007484      0.700900  1.000460      0.085797        21.601209

# %%
net.res_ext_grid
# Out:
#        p_mw   q_mvar
# 0 -2.699926 -1.50327

# %%
net.res_load
# Out:
#         p_mw    q_mvar
# 0   0.002199  0.000723
# 1   0.002199  0.000723
# 2   0.002199  0.000723
# 3   0.002199  0.000723
# 4   0.002199  0.000723
# ..       ...       ...
# 67  0.004940  0.001624
# 68  0.004940  0.001624
# 69  0.004940  0.001624
# 70  0.004940  0.001624
# 71  0.004940  0.001624
#
# [72 rows x 2 columns]

# %%
net.res_sgen
# Out:
#    p_mw  q_mvar
# 0   3.0     1.0

# %% [markdown]
# 2)
#
# a. No, there are no violations of voltage, line or transformers.

# %% [markdown]
# 3)
#
# a. No, there are no violations of voltage, line or transformers.

# %% [markdown]
# 4)
#
# a. Yes, The System is able to withstand with the load.

# %% [markdown]
# TASK 3 STARTS (SHORT CIRUIT ANALYSIS)

# %%
import pandapower as pp
import pandapower.shortcircuit as sc

# %%
sc.calc_sc(net, case="max", ip=True, ith=True, branch_results=True)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#       ikss_ka     skss_mw      ip_ka     ith_ka     rk_ohm      xk_ohm
# 0    0.587848  100.000000   1.100741   0.590740  43.969642  125.627547
# 1    2.391179   70.832867   4.770408   2.407425   1.517492    6.023599
# 2    2.072143   59.781143   3.578809   2.079945   3.082492    6.683599
# 3    1.950672   57.783918   3.324490   1.957491   3.395492    6.815599
# 4    1.886066   55.870123   3.163606   1.892239   3.708492    6.947599
# 5    1.950672   57.783918   3.324490   1.957491   3.395492    6.815599
# 6   10.917028    6.467809  21.444482  10.986104   0.007113    0.026265
# 7   10.883470    6.447927  21.306663  10.951297   0.007239    0.026318
# 8   10.917028    6.467809  21.444482  10.986104   0.007113    0.026265
# 9    3.410214    2.020386   5.021827   3.415835   0.066503    0.056265
# 10   1.946556    1.153240   2.828877   1.949389   0.125893    0.086265
# ...

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.725733  3.088911  1.732230
# 1   1.950672  3.324490  1.957491
# 2   1.886066  3.163606  1.892239
# 3   1.950672  3.324490  1.957491
# 4   3.410214  5.021827  3.415835
# 5   1.946556  2.828877  1.949389
# 6   1.358094  1.966985  1.359996
# 7   1.042138  1.507181  1.043572
# 8   0.845248  1.221470  0.846399
# 9   0.710859  1.026763  0.711821
# 10  0.613309  0.885570  0.614136
# 11  0.539286  0.778501  0.540010
# 12  3.405145  5.013973  3.410753
# 13  1.944859  2.826363  1.947690
# 14  1.357262  1.965765  1.359162
# 15  1.041646  1.506464  1.043079
# 16  0.844924  1.220999  0.846075
# 17  0.710629  1.026430  0.711591
# 18  0.613138  0.885322  0.613965
# 19  0.539153  0.778309  0.539878
# 20  3.410214  5.021827  3.415835
# 21  1.946556  2.828877  1.949389
# 22  1.358094  1.966985  1.359996
# 23  1.042138  1.507181  1.043572
# 24  0.845248  1.221470  0.846399
# 25  0.710859  1.026763  0.711821
# 26  0.613309  0.885570  0.614136
# ...

# %% [markdown]
# 3rd Task
#
# 1)
# C. Here ikss is the initial short-circuit current, ip is the peak short-circuit current and ith is the thermal equivalent    current.
#    And the ikss and ith have almost the same values, where as ip has the highest current when compared to both the current values.

# %% [markdown]
# 1)
# D. The shortcircuit module is used to calculate short-circuits according to DIN/IEC EN 60909.
#
#    The IEC 60909 International Standard is intended to give the methodology for the fault currents calculation in three-phase A.c. systems at a nominal frequency of 50 Hz. It describes universal practical process ensuring sufficiently accurate
# result with respect to degree of security.The short-circuit currents is considered as the sum of an a.c. symmetrical component and of an aperiodic component. The standard distinguishes between near to generation and far from generation short circuits. The methodology includes of a.c. motors contribution, too. In the present are used two numerical methods for short – circuit calculations.It is superposition method and equivalent voltage source method.
#
# Superposition method gives the short-circuit current only in relation to one assumed amount of the load. Hence, it need not lead to maximum short-circuit current in the system. For removing this lack, it was developed the equivalent voltage source method.

# %%
net.sgen.in_service = False

# %%
sc.calc_sc(net, case="max", ip=True, ith=True, branch_results=True)



net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka     skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.524864  100.000000   1.011668  0.527447  43.969642  125.627547
# 1   2.044769   70.832867   4.280510  2.058661   1.517492    6.023599
# 2   1.725733   59.781143   3.088911  1.732230   3.082492    6.683599
# 3   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 4   1.612832   55.870123   2.777194  1.618110   3.708492    6.947599
# 5   1.668078   57.783918   2.924842  1.673910   3.395492    6.815599
# 6   9.335478    6.467809  19.207832  9.394547   0.007113    0.026265
# 7   9.306782    6.447927  19.076889  9.364782   0.007239    0.026318
# 8   9.335478    6.467809  19.207832  9.394547   0.007113    0.026265
# 9   2.916176    2.020386   4.323152  2.920983   0.066503    0.056265
# 10  1.664558    1.153240   2.430072  1.666981   0.125893    0.086265
# ...

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.725733  3.088911  1.732230
# 1   1.668078  2.924842  1.673910
# 2   1.612832  2.777194  1.618110
# 3   1.668078  2.924842  1.673910
# 4   2.916176  4.323152  2.920983
# 5   1.664558  2.430072  1.666981
# 6   1.161347  1.688742  1.162973
# 7   0.891163  1.293671  0.892389
# 8   0.722797  1.048298  0.723782
# 9   0.607877  0.881124  0.608700
# 10  0.524459  0.759917  0.525166
# 11  0.461159  0.668014  0.461779
# 12  2.911841  4.316336  2.916637
# 13  1.663108  2.427905  1.665528
# 14  1.160635  1.687693  1.162260
# 15  0.890743  1.293054  0.891968
# 16  0.722520  1.047893  0.723504
# 17  0.607680  0.880838  0.608503
# 18  0.524313  0.759704  0.525019
# 19  0.461046  0.667849  0.461666
# 20  2.916176  4.323152  2.920983
# 21  1.664558  2.430072  1.666981
# 22  1.161347  1.688742  1.162973
# 23  0.891163  1.293671  0.892389
# 24  0.722797  1.048298  0.723782
# 25  0.607877  0.881124  0.608700
# 26  0.524459  0.759917  0.525166
# ...

# %% [markdown]
# 2)
#
# C. Here the ikss and ith have almost the same values, where as ip has the highest current when compared to both the current values.
#
# When compared with the values of Task1, the values of Task 1 are greater than Task 2 beacuse the sgen is in service.

# %%
import pandapower as pp
import pandapower.shortcircuit as sc

net.sgen.in_service = True

# %%
sc.calc_sc(net, topology="radial", ip=True, ith=True, r_fault_ohm=1.0, x_fault_ohm=1.5,  branch_results=True)

net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka    skss_mw     ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.581048  98.704543  1.084834  0.583878  44.969642  127.127547
# 1   1.947408  55.460188  3.612483  1.957422   2.517492    7.523599
# 2   1.735275  48.111706  2.924297  1.741334   4.082492    8.183599
# 3   1.633002  46.779523  2.730896  1.638397   4.395492    8.315599
# 4   1.586590  45.495973  2.622846  1.591574   4.708492    8.447599
# 5   1.633002  46.779523  2.730896  1.638397   4.395492    8.315599
# 6   1.720473   0.096249  2.463641  1.725087   1.007113    1.526265
# 7   1.715603   0.096243  2.456747  1.720204   1.007239    1.526318
# 8   1.720473   0.096249  2.463641  1.725087   1.007113    1.526265
# 9   0.628687   0.093288  0.916789  0.630315   1.066503    1.556265
# 10  0.412592   0.090478  0.608710  0.413627   1.125893    1.586265
# 11  0.323492   0.087811  0.480534  0.324279   1.185283    1.616265
# ...

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.388865  2.434400  1.393715
# 1   1.633002  2.730896  1.638397
# 2   1.586590  2.622846  1.591574
# 3   1.633002  2.730896  1.638397
# 4   0.628687  0.916789  0.630315
# 5   0.412592  0.608710  0.413627
# 6   0.323492  0.480534  0.324279
# 7   0.274063  0.408722  0.274712
# 8   0.242065  0.361782  0.242624
# 9   0.219292  0.328079  0.219787
# 10  0.202016  0.302315  0.202461
# 11  0.188298  0.281725  0.188705
# 12  0.627945  0.915733  0.629571
# 13  0.412338  0.608346  0.413372
# 14  0.323364  0.480349  0.324151
# 15  0.273985  0.408607  0.274634
# 16  0.242012  0.361703  0.242570
# 17  0.219253  0.328020  0.219747
# 18  0.201985  0.302268  0.202431
# 19  0.188273  0.281687  0.188680
# 20  0.628687  0.916789  0.630315
# 21  0.412592  0.608710  0.413627
# 22  0.323492  0.480534  0.324279
# 23  0.274063  0.408722  0.274712
# 24  0.242065  0.361782  0.242624
# 25  0.219292  0.328079  0.219787
# 26  0.202016  0.302315  0.202461
# ...

# %% [markdown]
# 3)
#
# C. Here the ikss and ith have almost the same values, where as ip has the highest current when compared to both the current values.
#
# When compared with the values of Task1, the values of Task 1 are greater than Task 3 beacuse here fault Impedance z = 1+1.5j ohm

# %%
sc.calc_sc(net, fault="2ph", ip=True, ith=True,  branch_results=True)
net.res_bus_sc
# Out:
# Branch results are in beta mode and might not always be reliable, especially for transformers
#      ikss_ka    skss_mw      ip_ka    ith_ka     rk_ohm      xk_ohm
# 0   0.517529  28.867513   0.965203  0.520076  43.969642  125.627547
# 1   2.117232  20.447687   4.196928  2.131617   1.517492    6.023599
# 2   1.840939  17.257330   3.164973  1.847870   3.082492    6.683599
# 3   1.727192  16.680780   2.932635  1.733230   3.395492    6.815599
# 4   1.669988  16.128315   2.791533  1.675453   3.708492    6.947599
# 5   1.727192  16.680780   2.932635  1.733230   3.395492    6.815599
# 6   9.666311   1.867096  18.871120  9.727473   0.007113    0.026265
# 7   9.636598   1.861356  18.750845  9.696654   0.007239    0.026318
# 8   9.666311   1.867096  18.871120  9.727473   0.007113    0.026265
# 9   3.019521   0.583235   4.442634  3.024498   0.066503    0.056265
# 10  1.723547   0.332912   2.503309  1.726056   0.125893    0.086265
# ...

# %%
net.res_line_sc
# Out:
#      ikss_ka     ip_ka    ith_ka
# 0   1.494529  2.675075  1.500155
# 1   1.727192  2.932635  1.733230
# 2   1.669988  2.791533  1.675453
# 3   1.727192  2.932635  1.733230
# 4   3.019521  4.442634  3.024498
# 5   1.723547  2.503309  1.726056
# 6   1.202503  1.740736  1.204187
# 7   0.922744  1.333862  0.924014
# 8   0.748411  1.081025  0.749431
# 9   0.629419  0.908715  0.630271
# 10  0.543045  0.783760  0.543777
# 11  0.477502  0.689004  0.478144
# 12  3.015032  4.435693  3.019998
# 13  1.722045  2.501085  1.724551
# 14  1.201766  1.739657  1.203449
# 15  0.922309  1.333227  0.923578
# 16  0.748125  1.080608  0.749144
# 17  0.629215  0.908420  0.630067
# 18  0.542893  0.783541  0.543625
# 19  0.477385  0.688834  0.478027
# 20  3.019521  4.442634  3.024498
# 21  1.723547  2.503309  1.726056
# 22  1.202503  1.740736  1.204187
# 23  0.922744  1.333862  0.924014
# 24  0.748411  1.081025  0.749431
# 25  0.629419  0.908715  0.630271
# 26  0.543045  0.783760  0.543777
# ...

# %% [markdown]
# 4)
#
# C. Here the ikss and ith have almost the same values, where as ip has the highest current when compared to both the current values.
#
# When compared with the values of Task1, the values of Task 1 are greater than Task 4 because we have computed the Max. Two Phase Short-Circuit Currents for Task 4.
